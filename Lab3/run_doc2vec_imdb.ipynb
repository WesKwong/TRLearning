# %%
# %matplotlib inline

# %% [markdown]
# How to reproduce the doc2vec 'Paragraph Vector' paper
# =====================================================
#
# Shows how to reproduce results of the "Distributed Representation of Sentences and Documents" paper by Le and Mikolov using Gensim.

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# Introduction
# ------------
#
# This guide shows you how to reproduce the results of the paper by `Le and
# Mikolov 2014 <https://arxiv.org/pdf/1405.4053.pdf>`_ using Gensim. While the
# entire paper is worth reading (it's only 9 pages), we will be focusing on
# Section 3.2: "Beyond One Sentence - Sentiment Analysis with the IMDB
# dataset".
#
# This guide follows the following steps:
#
# #. Load the IMDB dataset
# #. Train a variety of Doc2Vec models on the dataset
# #. Evaluate the performance of each model using a logistic regression
# #. Examine some of the results directly:
#
# When examining results, we will look for answers for the following questions:
#
# #. Are inferred vectors close to the precalculated ones?
# #. Do close documents seem more related than distant ones?
# #. Do the word vectors show useful similarities?
# #. Are the word vectors from this dataset any good at analogies?
#
# Load corpus
# -----------
#
# Our data for the tutorial will be the `IMDB archive
# <http://ai.stanford.edu/~amaas/data/sentiment/>`_.
# If you're not familiar with this dataset, then here's a brief intro: it
# contains several thousand movie reviews.
#
# Each review is a single line of text containing multiple sentences, for example:
#
# ```
# One of the best movie-dramas I have ever seen. We do a lot of acting in the
# church and this is one that can be used as a resource that highlights all the
# good things that actors can do in their work. I highly recommend this one,
# especially for those who have an interest in acting, as a "must see."
# ```
#
# These reviews will be the **documents** that we will work with in this tutorial.
# There are 100 thousand reviews in total.
#
# #. 25k reviews for training (12.5k positive, 12.5k negative)
# #. 25k reviews for testing (12.5k positive, 12.5k negative)
# #. 50k unlabeled reviews
#
# Out of 100k reviews, 50k have a label: either positive (the reviewer liked
# the movie) or negative.
# The remaining 50k are unlabeled.
#
# Our first task will be to prepare the dataset.
#
# More specifically, we will:
#
# #. Download the tar.gz file (it's only 84MB, so this shouldn't take too long)
# #. Unpack it and extract each movie review
# #. Split the reviews into training and test datasets
#
# First, let's define a convenient datatype for holding data for a single document:
#
# * words: The text of the document, as a ``list`` of words.
# * tags: Used to keep the index of the document in the entire dataset.
# * split: one of ``train``\ , ``test`` or ``extra``. Determines how the document will be used (for training, testing, etc).
# * sentiment: either 1 (positive), 0 (negative) or None (unlabeled document).
#
# This data type is helpful for later evaluation and reporting.
# In particular, the ``index`` member will help us quickly and easily retrieve the vectors for a document from a model.

# %%
import collections

SentimentDocument = collections.namedtuple('SentimentDocument', 'words tags split sentiment')

# %% [markdown]
# We can now proceed with loading the corpus.

# %%
import io
import re
import tarfile
import os.path

import smart_open
import gensim.utils

def download_dataset(url='http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz'):
    fname = url.split('/')[-1]

    if os.path.isfile(fname):
       return fname

    # Download the file to local storage first.
    with smart_open.open(url, "rb", ignore_ext=True) as fin:
        with smart_open.open(fname, 'wb', ignore_ext=True) as fout:
            while True:
                buf = fin.read(io.DEFAULT_BUFFER_SIZE)
                if not buf:
                    break
                fout.write(buf)

    return fname

def create_sentiment_document(name, text, index):
    _, split, sentiment_str, _ = name.split('/')
    sentiment = {'pos': 1.0, 'neg': 0.0, 'unsup': None}[sentiment_str]

    if sentiment is None:
        split = 'extra'

    tokens = gensim.utils.to_unicode(text).split()
    return SentimentDocument(tokens, [index], split, sentiment)

def extract_documents(file_path):

    index = 0

    with tarfile.open(file_path, mode='r:gz') as tar:
        for member in tar.getmembers():
            if re.match(r'aclImdb/(train|test)/(pos|neg|unsup)/\d+_\d+.txt$', member.name):
                member_bytes = tar.extractfile(member).read()
                member_text = member_bytes.decode('utf-8', errors='replace')
                assert member_text.count('\n') == 0
                yield create_sentiment_document(member.name, member_text, index)
                index += 1

# %%
# fname = download_dataset()
# alldocs = list(extract_documents(filename))
data_path = "./data/aclImdb_v1.tar.gz"
alldocs = list(extract_documents(data_path))

# %% [markdown]
# Here's what a single document looks like.

# %%
print(alldocs[27])
# Out:
# SentimentDocument(words=['I', 'was', 'looking', 'forward', 'to', 'this', 'movie.', 'Trustworthy', 'actors,', 'interesting', 'plot.', 'Great', 'atmosphere', 'then', '?????', 'IF', 'you', 'are', 'going', 'to', 'attempt', 'something', 'that', 'is', 'meant', 'to', 'encapsulate', 'the', 'meaning', 'of', 'life.', 'First.', 'Know', 'it.', 'OK', 'I', 'did', 'not', 'expect', 'the', 'directors', 'or', 'writers', 'to', 'actually', 'know', 'the', 'meaning', 'but', 'I', 'thought', 'they', 'may', 'have', 'offered', 'crumbs', 'to', 'peck', 'at', 'and', 'treats', 'to', 'add', 'fuel', 'to', 'the', 'fire-Which!', 'they', 'almost', 'did.', 'Things', 'I', "didn't", 'get.', 'A', 'woman', 'wandering', 'around', 'in', 'dark', 'places', 'and', 'lonely', 'car', 'parks', 'alone-oblivious', 'to', 'the', 'consequences.', 'Great', 'riddles', 'that', 'fell', 'by', 'the', 'wayside.', 'The', 'promise', 'of', 'the', 'knowledge', 'therein', 'contained', 'by', 'the', 'original', 'so-called', 'criminal.', 'I', 'had', 'no', 'problem', 'with', 'the', 'budget', 'and', 'enjoyed', 'the', 'suspense.', 'I', 'understood', 'and', 'can', 'wax', 'lyrical', 'about', 'the', 'fool', 'and', 'found', 'Adrian', 'Pauls', 'role', 'crucial', 'and', 'penetrating', 'and', 'then', '?????', 'Basically', 'the', 'story', 'line', 'and', 'the', 'script', 'where', 'good', 'up', 'to', 'a', 'point', 'and', 'that', 'point', 'was', 'the', 'last', '10', 'minutes', 'or', 'so.', 'What?', 'Run', 'out', 'of', 'ideas!', 'Such', 'a', 'pity', 'that', 'this', 'movie', 'had', 'to', 'let', 'us', 'down', 'so', 'badly.', 'It', 'may', 'not', 'comprehend', 'the', 'meaning', 'and', 'I', 'really', 'did', 'not', 'expect', 'the', 'writers', 'to', 'understand', 'it', 'but', 'I', 'was', 'hoping', 'for', 'an', 'intellectual,', 'if', 'not', 'spiritual', 'ride', 'and', 'got', 'a', 'bump', 'in', 'the', 'road'], tags=[27], split='test', sentiment=0.0)

# %% [markdown]
# Extract our documents and split into training/test sets.

# %%
train_docs = [doc for doc in alldocs if doc.split == 'train']
test_docs = [doc for doc in alldocs if doc.split == 'test']
print(f'{len(alldocs)} docs: {len(train_docs)} train-sentiment, {len(test_docs)} test-sentiment')
# Out:
# 100000 docs: 25000 train-sentiment, 25000 test-sentiment

# %% [markdown]
# Set-up Doc2Vec Training & Evaluation Models
# -------------------------------------------
#
# We approximate the experiment of Le & Mikolov `"Distributed Representations
# of Sentences and Documents"
# <http://cs.stanford.edu/~quocle/paragraph_vector.pdf>`_ with guidance from
# Mikolov's `example go.sh
# <https://groups.google.com/d/msg/word2vec-toolkit/Q49FIrNOQRo/J6KG8mUj45sJ>`_::
#
#     ./word2vec -train ../alldata-id.txt -output vectors.txt -cbow 0 -size 100 -window 10 -negative 5 -hs 0 -sample 1e-4 -threads 40 -binary 0 -iter 20 -min-count 1 -sentence-vectors 1
#
# We vary the following parameter choices:
#
# * 100-dimensional vectors, as the 400-d vectors of the paper take a lot of
#   memory and, in our tests of this task, don't seem to offer much benefit
# * Similarly, frequent word subsampling seems to decrease sentiment-prediction
#   accuracy, so it's left out
# * ``cbow=0`` means skip-gram which is equivalent to the paper's 'PV-DBOW'
#   mode, matched in gensim with ``dm=0``
# * Added to that DBOW model are two DM models, one which averages context
#   vectors (\ ``dm_mean``\ ) and one which concatenates them (\ ``dm_concat``\ ,
#   resulting in a much larger, slower, more data-hungry model)
# * A ``min_count=2`` saves quite a bit of model memory, discarding only words
#   that appear in a single doc (and are thus no more expressive than the
#   unique-to-each doc vectors themselves)

# %%
import multiprocessing
from collections import OrderedDict

import gensim.models.doc2vec
assert gensim.models.doc2vec.FAST_VERSION > -1, "This will be painfully slow otherwise"

from gensim.models.doc2vec import Doc2Vec

common_kwargs = dict(
    vector_size=100, epochs=20, min_count=2,
    sample=0, workers=multiprocessing.cpu_count(), negative=5, hs=0,
)

simple_models = [
    # PV-DBOW plain
    Doc2Vec(dm=0, **common_kwargs),
    # PV-DM w/ default averaging; a higher starting alpha may improve CBOW/PV-DM modes
    Doc2Vec(dm=1, window=10, alpha=0.05, comment='alpha=0.05', **common_kwargs),
    # PV-DM w/ concatenation - big, slow, experimental mode
    # window=5 (both sides) approximates paper's apparent 10-word total window size
    Doc2Vec(dm=1, dm_concat=1, window=5, **common_kwargs),
]

for model in simple_models:
    model.build_vocab(alldocs)
    print(f"{model} vocabulary scanned & state initialized")

models_by_name = OrderedDict((str(model), model) for model in simple_models)
# Out:
# 2024-05-07 20:39:56,438 : INFO : Doc2Vec lifecycle event {'params': 'Doc2Vec<dbow,d100,n5,mc2,t48>', 'datetime': '2024-05-07T20:39:56.438724', 'gensim': '4.3.2', 'python': '3.9.18 | packaged by conda-forge | (main, Dec 23 2023, 16:33:10) \n[GCC 12.3.0]', 'platform': 'Linux-4.15.0-213-generic-x86_64-with-glibc2.27', 'event': 'created'}
# 2024-05-07 20:39:56,441 : INFO : Doc2Vec lifecycle event {'params': 'Doc2Vec<dm/m,d100,n5,w10,mc2,t48>', 'datetime': '2024-05-07T20:39:56.441952', 'gensim': '4.3.2', 'python': '3.9.18 | packaged by conda-forge | (main, Dec 23 2023, 16:33:10) \n[GCC 12.3.0]', 'platform': 'Linux-4.15.0-213-generic-x86_64-with-glibc2.27', 'event': 'created'}
# 2024-05-07 20:39:56,442 : INFO : using concatenative 1100-dimensional layer1
# 2024-05-07 20:39:56,445 : INFO : Doc2Vec lifecycle event {'params': 'Doc2Vec<dm/c,d100,n5,w5,mc2,t48>', 'datetime': '2024-05-07T20:39:56.444971', 'gensim': '4.3.2', 'python': '3.9.18 | packaged by conda-forge | (main, Dec 23 2023, 16:33:10) \n[GCC 12.3.0]', 'platform': 'Linux-4.15.0-213-generic-x86_64-with-glibc2.27', 'event': 'created'}
# 2024-05-07 20:39:56,445 : INFO : collecting all words and their counts
# 2024-05-07 20:39:56,446 : INFO : PROGRESS: at example #0, processed 0 words (0 words/s), 0 word types, 0 tags
# 2024-05-07 20:39:56,998 : INFO : PROGRESS: at example #10000, processed 2292381 words (4157070 words/s), 150816 word types, 0 tags
# 2024-05-07 20:39:57,534 : INFO : PROGRESS: at example #20000, processed 4573645 words (4274787 words/s), 238497 word types, 0 tags
# 2024-05-07 20:39:58,131 : INFO : PROGRESS: at example #30000, processed 6865575 words (3855196 words/s), 312348 word types, 0 tags
# 2024-05-07 20:39:58,806 : INFO : PROGRESS: at example #40000, processed 9190019 words (3456645 words/s), 377231 word types, 0 tags
# 2024-05-07 20:39:59,458 : INFO : PROGRESS: at example #50000, processed 11557847 words (3635989 words/s), 438729 word types, 0 tags
# 2024-05-07 20:40:00,095 : INFO : PROGRESS: at example #60000, processed 13899883 words (3707990 words/s), 493913 word types, 0 tags
# 2024-05-07 20:40:00,693 : INFO : PROGRESS: at example #70000, processed 16270094 words (3978311 words/s), 548474 word types, 0 tags
# 2024-05-07 20:40:01,319 : INFO : PROGRESS: at example #80000, processed 18598876 words (3726768 words/s), 598272 word types, 0 tags
# 2024-05-07 20:40:01,936 : INFO : PROGRESS: at example #90000, processed 20916044 words (3770010 words/s), 646082 word types, 0 tags
# 2024-05-07 20:40:02,533 : INFO : collected 693922 word types and 100000 unique tags from a corpus of 100000 examples and 23279529 words
# 2024-05-07 20:40:02,535 : INFO : Creating a fresh vocabulary
# 2024-05-07 20:40:03,944 : INFO : Doc2Vec lifecycle event {'msg': 'effective_min_count=2 retains 265408 unique words (38.25% of original 693922, drops 428514)', 'datetime': '2024-05-07T20:40:03.944370', 'gensim': '4.3.2', 'python': '3.9.18 | packaged by conda-forge | (main, Dec 23 2023, 16:33:10) \n[GCC 12.3.0]', 'platform': 'Linux-4.15.0-213-generic-x86_64-with-glibc2.27', 'event': 'prepare_vocab'}
# 2024-05-07 20:40:03,947 : INFO : Doc2Vec lifecycle event {'msg': 'effective_min_count=2 leaves 22851015 word corpus (98.16% of original 23279529, drops 428514)', 'datetime': '2024-05-07T20:40:03.947456', 'gensim': '4.3.2', 'python': '3.9.18 | packaged by conda-forge | (main, Dec 23 2023, 16:33:10) \n[GCC 12.3.0]', 'platform': 'Linux-4.15.0-213-generic-x86_64-with-glibc2.27', 'event': 'prepare_vocab'}
# 2024-05-07 20:40:05,373 : INFO : deleting the raw counts dictionary of 693922 items
# 2024-05-07 20:40:05,406 : INFO : sample=0 downsamples 0 most-common words
# 2024-05-07 20:40:05,408 : INFO : Doc2Vec lifecycle event {'msg': 'downsampling leaves estimated 22851015 word corpus (100.0%% of prior 22851015)', 'datetime': '2024-05-07T20:40:05.408176', 'gensim': '4.3.2', 'python': '3.9.18 | packaged by conda-forge | (main, Dec 23 2023, 16:33:10) \n[GCC 12.3.0]', 'platform': 'Linux-4.15.0-213-generic-x86_64-with-glibc2.27', 'event': 'prepare_vocab'}
# 2024-05-07 20:40:07,625 : INFO : estimated required memory for 265408 words and 100 dimensions: 405030400 bytes
# 2024-05-07 20:40:07,627 : INFO : resetting layer weights
# 2024-05-07 20:40:07,842 : INFO : collecting all words and their counts
# 2024-05-07 20:40:07,844 : INFO : PROGRESS: at example #0, processed 0 words (0 words/s), 0 word types, 0 tags
# Doc2Vec<dbow,d100,n5,mc2,t48> vocabulary scanned & state initialized
# 2024-05-07 20:40:08,310 : INFO : PROGRESS: at example #10000, processed 2292381 words (4919791 words/s), 150816 word types, 0 tags
# 2024-05-07 20:40:08,789 : INFO : PROGRESS: at example #20000, processed 4573645 words (4774673 words/s), 238497 word types, 0 tags
# 2024-05-07 20:40:09,282 : INFO : PROGRESS: at example #30000, processed 6865575 words (4661119 words/s), 312348 word types, 0 tags
# 2024-05-07 20:40:09,879 : INFO : PROGRESS: at example #40000, processed 9190019 words (3906690 words/s), 377231 word types, 0 tags
# 2024-05-07 20:40:10,415 : INFO : PROGRESS: at example #50000, processed 11557847 words (4420429 words/s), 438729 word types, 0 tags
# 2024-05-07 20:40:11,009 : INFO : PROGRESS: at example #60000, processed 13899883 words (3954589 words/s), 493913 word types, 0 tags
# 2024-05-07 20:40:11,620 : INFO : PROGRESS: at example #70000, processed 16270094 words (3884410 words/s), 548474 word types, 0 tags
# 2024-05-07 20:40:12,194 : INFO : PROGRESS: at example #80000, processed 18598876 words (4097322 words/s), 598272 word types, 0 tags
# 2024-05-07 20:40:12,749 : INFO : PROGRESS: at example #90000, processed 20916044 words (4189996 words/s), 646082 word types, 0 tags
# 2024-05-07 20:40:13,353 : INFO : collected 693922 word types and 100000 unique tags from a corpus of 100000 examples and 23279529 words
# 2024-05-07 20:40:13,354 : INFO : Creating a fresh vocabulary
# 2024-05-07 20:40:14,538 : INFO : Doc2Vec lifecycle event {'msg': 'effective_min_count=2 retains 265408 unique words (38.25% of original 693922, drops 428514)', 'datetime': '2024-05-07T20:40:14.538299', 'gensim': '4.3.2', 'python': '3.9.18 | packaged by conda-forge | (main, Dec 23 2023, 16:33:10) \n[GCC 12.3.0]', 'platform': 'Linux-4.15.0-213-generic-x86_64-with-glibc2.27', 'event': 'prepare_vocab'}
# 2024-05-07 20:40:14,540 : INFO : Doc2Vec lifecycle event {'msg': 'effective_min_count=2 leaves 22851015 word corpus (98.16% of original 23279529, drops 428514)', 'datetime': '2024-05-07T20:40:14.540681', 'gensim': '4.3.2', 'python': '3.9.18 | packaged by conda-forge | (main, Dec 23 2023, 16:33:10) \n[GCC 12.3.0]', 'platform': 'Linux-4.15.0-213-generic-x86_64-with-glibc2.27', 'event': 'prepare_vocab'}
# 2024-05-07 20:40:15,907 : INFO : deleting the raw counts dictionary of 693922 items
# 2024-05-07 20:40:15,924 : INFO : sample=0 downsamples 0 most-common words
# 2024-05-07 20:40:15,926 : INFO : Doc2Vec lifecycle event {'msg': 'downsampling leaves estimated 22851015 word corpus (100.0%% of prior 22851015)', 'datetime': '2024-05-07T20:40:15.926037', 'gensim': '4.3.2', 'python': '3.9.18 | packaged by conda-forge | (main, Dec 23 2023, 16:33:10) \n[GCC 12.3.0]', 'platform': 'Linux-4.15.0-213-generic-x86_64-with-glibc2.27', 'event': 'prepare_vocab'}
# 2024-05-07 20:40:18,096 : INFO : estimated required memory for 265408 words and 100 dimensions: 405030400 bytes
# 2024-05-07 20:40:18,097 : INFO : resetting layer weights
# 2024-05-07 20:40:18,303 : INFO : collecting all words and their counts
# 2024-05-07 20:40:18,304 : INFO : PROGRESS: at example #0, processed 0 words (0 words/s), 0 word types, 0 tags
# Doc2Vec<dm/m,d100,n5,w10,mc2,t48> vocabulary scanned & state initialized
# 2024-05-07 20:40:18,816 : INFO : PROGRESS: at example #10000, processed 2292381 words (4489958 words/s), 150816 word types, 0 tags
# 2024-05-07 20:40:19,275 : INFO : PROGRESS: at example #20000, processed 4573645 words (4978433 words/s), 238497 word types, 0 tags
# 2024-05-07 20:40:19,753 : INFO : PROGRESS: at example #30000, processed 6865575 words (4805054 words/s), 312348 word types, 0 tags
# 2024-05-07 20:40:20,237 : INFO : PROGRESS: at example #40000, processed 9190019 words (4804720 words/s), 377231 word types, 0 tags
# 2024-05-07 20:40:20,735 : INFO : PROGRESS: at example #50000, processed 11557847 words (4768502 words/s), 438729 word types, 0 tags
# 2024-05-07 20:40:21,217 : INFO : PROGRESS: at example #60000, processed 13899883 words (4861162 words/s), 493913 word types, 0 tags
# 2024-05-07 20:40:21,731 : INFO : PROGRESS: at example #70000, processed 16270094 words (4620900 words/s), 548474 word types, 0 tags
# 2024-05-07 20:40:22,248 : INFO : PROGRESS: at example #80000, processed 18598876 words (4511806 words/s), 598272 word types, 0 tags
# 2024-05-07 20:40:22,785 : INFO : PROGRESS: at example #90000, processed 20916044 words (4321538 words/s), 646082 word types, 0 tags
# 2024-05-07 20:40:23,339 : INFO : collected 693922 word types and 100000 unique tags from a corpus of 100000 examples and 23279529 words
# 2024-05-07 20:40:23,340 : INFO : Creating a fresh vocabulary
# 2024-05-07 20:40:24,497 : INFO : Doc2Vec lifecycle event {'msg': 'effective_min_count=2 retains 265408 unique words (38.25% of original 693922, drops 428514)', 'datetime': '2024-05-07T20:40:24.497101', 'gensim': '4.3.2', 'python': '3.9.18 | packaged by conda-forge | (main, Dec 23 2023, 16:33:10) \n[GCC 12.3.0]', 'platform': 'Linux-4.15.0-213-generic-x86_64-with-glibc2.27', 'event': 'prepare_vocab'}
# 2024-05-07 20:40:24,498 : INFO : Doc2Vec lifecycle event {'msg': 'effective_min_count=2 leaves 22851015 word corpus (98.16% of original 23279529, drops 428514)', 'datetime': '2024-05-07T20:40:24.497983', 'gensim': '4.3.2', 'python': '3.9.18 | packaged by conda-forge | (main, Dec 23 2023, 16:33:10) \n[GCC 12.3.0]', 'platform': 'Linux-4.15.0-213-generic-x86_64-with-glibc2.27', 'event': 'prepare_vocab'}
# 2024-05-07 20:40:25,894 : INFO : deleting the raw counts dictionary of 693922 items
# 2024-05-07 20:40:25,931 : INFO : sample=0 downsamples 0 most-common words
# 2024-05-07 20:40:25,932 : INFO : Doc2Vec lifecycle event {'msg': 'downsampling leaves estimated 22851015 word corpus (100.0%% of prior 22851015)', 'datetime': '2024-05-07T20:40:25.932704', 'gensim': '4.3.2', 'python': '3.9.18 | packaged by conda-forge | (main, Dec 23 2023, 16:33:10) \n[GCC 12.3.0]', 'platform': 'Linux-4.15.0-213-generic-x86_64-with-glibc2.27', 'event': 'prepare_vocab'}
# 2024-05-07 20:40:28,174 : INFO : estimated required memory for 265408 words and 100 dimensions: 1466662400 bytes
# 2024-05-07 20:40:28,175 : INFO : resetting layer weights
# Doc2Vec<dm/c,d100,n5,w5,mc2,t48> vocabulary scanned & state initialized

# %% [markdown]
# Le and Mikolov note that combining a paragraph vector from Distributed Bag of
# Words (DBOW) and Distributed Memory (DM) improves performance. We will
# follow, pairing the models together for evaluation. Here, we concatenate the
# paragraph vectors obtained from each model with the help of a thin wrapper
# class included in a gensim test module. (Note that this a separate, later
# concatenation of output-vectors than the kind of input-window-concatenation
# enabled by the ``dm_concat=1`` mode above.)

# %%
from gensim.test.test_doc2vec import ConcatenatedDoc2Vec
models_by_name['dbow+dmm'] = ConcatenatedDoc2Vec([simple_models[0], simple_models[1]])
models_by_name['dbow+dmc'] = ConcatenatedDoc2Vec([simple_models[0], simple_models[2]])
# Out:
# 2024-05-07 20:48:16,075 : INFO : adding document #0 to Dictionary<0 unique tokens: []>
# 2024-05-07 20:48:16,076 : INFO : built Dictionary<12 unique tokens: ['computer', 'human', 'interface', 'response', 'survey']...> from 9 documents (total 29 corpus positions)
# 2024-05-07 20:48:16,078 : INFO : Dictionary lifecycle event {'msg': "built Dictionary<12 unique tokens: ['computer', 'human', 'interface', 'response', 'survey']...> from 9 documents (total 29 corpus positions)", 'datetime': '2024-05-07T20:48:16.077933', 'gensim': '4.3.2', 'python': '3.9.18 | packaged by conda-forge | (main, Dec 23 2023, 16:33:10) \n[GCC 12.3.0]', 'platform': 'Linux-4.15.0-213-generic-x86_64-with-glibc2.27', 'event': 'created'}

# %% [markdown]
# Predictive Evaluation Methods
# -----------------------------
#
# Given a document, our ``Doc2Vec`` models output a vector representation of the document.
# How useful is a particular model?
# In case of sentiment analysis, we want the ouput vector to reflect the sentiment in the input document.
# So, in vector space, positive documents should be distant from negative documents.
#
# We train a logistic regression from the training set:
#
#   - regressors (inputs): document vectors from the Doc2Vec model
#   - target (outpus): sentiment labels
#
# So, this logistic regression will be able to predict sentiment given a document vector.
#
# Next, we test our logistic regression on the test set, and measure the rate of errors (incorrect predictions).
# If the document vectors from the Doc2Vec model reflect the actual sentiment well, the error rate will be low.
#
# Therefore, the error rate of the logistic regression is indication of *how well* the given Doc2Vec model represents documents as vectors.
# We can then compare different ``Doc2Vec`` models by looking at their error rates.

# %%
import numpy as np
import statsmodels.api as sm
from random import sample

def logistic_predictor_from_data(train_targets, train_regressors):
    """Fit a statsmodel logistic predictor on supplied data"""
    logit = sm.Logit(train_targets, train_regressors)
    predictor = logit.fit(disp=0)
    # print(predictor.summary())
    return predictor

def error_rate_for_model(test_model, train_set, test_set):
    """Report error rate on test_doc sentiments, using supplied model and train_docs"""

    train_targets = [doc.sentiment for doc in train_set]
    train_regressors = [test_model.dv[doc.tags[0]] for doc in train_set]
    train_regressors = sm.add_constant(train_regressors)
    predictor = logistic_predictor_from_data(train_targets, train_regressors)

    test_regressors = [test_model.dv[doc.tags[0]] for doc in test_set]
    test_regressors = sm.add_constant(test_regressors)

    # Predict & evaluate
    test_predictions = predictor.predict(test_regressors)
    corrects = sum(np.rint(test_predictions) == [doc.sentiment for doc in test_set])
    errors = len(test_predictions) - corrects
    error_rate = float(errors) / len(test_predictions)
    return (error_rate, errors, len(test_predictions), predictor)

# %% [markdown]
# Bulk Training & Per-Model Evaluation
# ------------------------------------
#
# Note that doc-vector training is occurring on *all* documents of the dataset,
# which includes all TRAIN/TEST/DEV docs.  Because the native document-order
# has similar-sentiment documents in large clumps – which is suboptimal for
# training – we work with once-shuffled copy of the training set.
#
# We evaluate each model's sentiment predictive power based on error rate, and
# the evaluation is done for each model.
#
# (On a 4-core 2.6Ghz Intel Core i7, these 20 passes training and evaluating 3
# main models takes about an hour.)

# %%
from collections import defaultdict
error_rates = defaultdict(lambda: 1.0)  # To selectively print only best errors achieved

# %%
from random import shuffle
shuffled_alldocs = alldocs[:]
shuffle(shuffled_alldocs)

for model in simple_models:
    print(f"Training {model}")
    model.train(shuffled_alldocs, total_examples=len(shuffled_alldocs), epochs=model.epochs)

    print(f"\nEvaluating {model}")
    err_rate, err_count, test_count, predictor = error_rate_for_model(model, train_docs, test_docs)
    error_rates[str(model)] = err_rate
    print("\n%f %s\n" % (err_rate, model))

for model in [models_by_name['dbow+dmm'], models_by_name['dbow+dmc']]:
    print(f"\nEvaluating {model}")
    err_rate, err_count, test_count, predictor = error_rate_for_model(model, train_docs, test_docs)
    error_rates[str(model)] = err_rate
    print(f"\n{err_rate} {model}\n")
# Out:
# 2024-05-07 20:52:33,757 : INFO : Doc2Vec lifecycle event {'msg': 'training model with 48 workers on 265408 vocabulary and 100 features, using sg=1 hs=0 sample=0 negative=5 window=5 shrink_windows=True', 'datetime': '2024-05-07T20:52:33.757010', 'gensim': '4.3.2', 'python': '3.9.18 | packaged by conda-forge | (main, Dec 23 2023, 16:33:10) \n[GCC 12.3.0]', 'platform': 'Linux-4.15.0-213-generic-x86_64-with-glibc2.27', 'event': 'train'}
# Training Doc2Vec<dbow,d100,n5,mc2,t48>
# 2024-05-07 20:52:34,852 : INFO : EPOCH 0 - PROGRESS: at 2.03% examples, 438913 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 20:52:35,871 : INFO : EPOCH 0 - PROGRESS: at 5.15% examples, 573782 words/s, in_qsize 85, out_qsize 10
# 2024-05-07 20:52:36,942 : INFO : EPOCH 0 - PROGRESS: at 8.50% examples, 624579 words/s, in_qsize 95, out_qsize 3
# 2024-05-07 20:52:37,977 : INFO : EPOCH 0 - PROGRESS: at 11.82% examples, 650652 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:52:39,026 : INFO : EPOCH 0 - PROGRESS: at 15.14% examples, 666371 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 20:52:40,035 : INFO : EPOCH 0 - PROGRESS: at 18.63% examples, 687482 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:52:41,049 : INFO : EPOCH 0 - PROGRESS: at 21.50% examples, 682103 words/s, in_qsize 94, out_qsize 2
# 2024-05-07 20:52:42,105 : INFO : EPOCH 0 - PROGRESS: at 24.54% examples, 679386 words/s, in_qsize 96, out_qsize 3
# 2024-05-07 20:52:43,110 : INFO : EPOCH 0 - PROGRESS: at 27.41% examples, 675653 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:52:44,158 : INFO : EPOCH 0 - PROGRESS: at 30.41% examples, 673563 words/s, in_qsize 96, out_qsize 7
# 2024-05-07 20:52:45,224 : INFO : EPOCH 0 - PROGRESS: at 33.27% examples, 667726 words/s, in_qsize 93, out_qsize 8
# 2024-05-07 20:52:46,233 : INFO : EPOCH 0 - PROGRESS: at 36.69% examples, 676433 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 20:52:47,240 : INFO : EPOCH 0 - PROGRESS: at 39.60% examples, 676231 words/s, in_qsize 93, out_qsize 5
# 2024-05-07 20:52:48,268 : INFO : EPOCH 0 - PROGRESS: at 42.77% examples, 678154 words/s, in_qsize 96, out_qsize 4
# 2024-05-07 20:52:49,279 : INFO : EPOCH 0 - PROGRESS: at 45.92% examples, 680740 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 20:52:50,330 : INFO : EPOCH 0 - PROGRESS: at 49.13% examples, 680796 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:52:51,335 : INFO : EPOCH 0 - PROGRESS: at 52.26% examples, 682632 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:52:52,364 : INFO : EPOCH 0 - PROGRESS: at 55.47% examples, 684288 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 20:52:53,373 : INFO : EPOCH 0 - PROGRESS: at 58.75% examples, 687651 words/s, in_qsize 83, out_qsize 0
# 2024-05-07 20:52:54,375 : INFO : EPOCH 0 - PROGRESS: at 61.42% examples, 683343 words/s, in_qsize 93, out_qsize 10
# 2024-05-07 20:52:55,394 : INFO : EPOCH 0 - PROGRESS: at 65.06% examples, 689182 words/s, in_qsize 95, out_qsize 4
# 2024-05-07 20:52:56,399 : INFO : EPOCH 0 - PROGRESS: at 68.39% examples, 691977 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:52:57,492 : INFO : EPOCH 0 - PROGRESS: at 71.64% examples, 691459 words/s, in_qsize 96, out_qsize 8
# 2024-05-07 20:52:58,513 : INFO : EPOCH 0 - PROGRESS: at 75.04% examples, 694968 words/s, in_qsize 94, out_qsize 3
# 2024-05-07 20:52:59,531 : INFO : EPOCH 0 - PROGRESS: at 78.38% examples, 697564 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 20:53:00,534 : INFO : EPOCH 0 - PROGRESS: at 81.49% examples, 698235 words/s, in_qsize 92, out_qsize 1
# 2024-05-07 20:53:01,569 : INFO : EPOCH 0 - PROGRESS: at 85.12% examples, 702556 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:53:02,603 : INFO : EPOCH 0 - PROGRESS: at 88.33% examples, 703274 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:53:03,612 : INFO : EPOCH 0 - PROGRESS: at 91.83% examples, 706731 words/s, in_qsize 91, out_qsize 0
# 2024-05-07 20:53:04,636 : INFO : EPOCH 0 - PROGRESS: at 95.16% examples, 707794 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:53:05,654 : INFO : EPOCH 0 - PROGRESS: at 98.48% examples, 709793 words/s, in_qsize 32, out_qsize 7
# 2024-05-07 20:53:05,791 : INFO : EPOCH 0: training on 23279529 raw words (22951015 effective words) took 32.0s, 717215 effective words/s
# 2024-05-07 20:53:06,842 : INFO : EPOCH 1 - PROGRESS: at 2.13% examples, 483675 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 20:53:07,850 : INFO : EPOCH 1 - PROGRESS: at 5.57% examples, 635280 words/s, in_qsize 92, out_qsize 3
# 2024-05-07 20:53:08,880 : INFO : EPOCH 1 - PROGRESS: at 8.52% examples, 643064 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:53:09,889 : INFO : EPOCH 1 - PROGRESS: at 11.68% examples, 659778 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:53:10,911 : INFO : EPOCH 1 - PROGRESS: at 14.93% examples, 675785 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:53:11,974 : INFO : EPOCH 1 - PROGRESS: at 18.02% examples, 675343 words/s, in_qsize 93, out_qsize 4
# 2024-05-07 20:53:13,013 : INFO : EPOCH 1 - PROGRESS: at 21.56% examples, 689640 words/s, in_qsize 96, out_qsize 4
# 2024-05-07 20:53:14,028 : INFO : EPOCH 1 - PROGRESS: at 25.16% examples, 704609 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:53:15,032 : INFO : EPOCH 1 - PROGRESS: at 27.96% examples, 697086 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:53:16,067 : INFO : EPOCH 1 - PROGRESS: at 31.26% examples, 700423 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:53:17,068 : INFO : EPOCH 1 - PROGRESS: at 34.36% examples, 700950 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:53:18,102 : INFO : EPOCH 1 - PROGRESS: at 37.20% examples, 694728 words/s, in_qsize 95, out_qsize 3
# 2024-05-07 20:53:19,129 : INFO : EPOCH 1 - PROGRESS: at 40.07% examples, 691185 words/s, in_qsize 92, out_qsize 1
# 2024-05-07 20:53:20,145 : INFO : EPOCH 1 - PROGRESS: at 43.13% examples, 691394 words/s, in_qsize 94, out_qsize 2
# 2024-05-07 20:53:21,197 : INFO : EPOCH 1 - PROGRESS: at 46.31% examples, 691245 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:53:22,229 : INFO : EPOCH 1 - PROGRESS: at 49.56% examples, 692055 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:53:23,261 : INFO : EPOCH 1 - PROGRESS: at 52.35% examples, 687803 words/s, in_qsize 96, out_qsize 3
# 2024-05-07 20:53:24,291 : INFO : EPOCH 1 - PROGRESS: at 55.95% examples, 693865 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 20:53:25,329 : INFO : EPOCH 1 - PROGRESS: at 58.94% examples, 692145 words/s, in_qsize 96, out_qsize 5
# 2024-05-07 20:53:26,350 : INFO : EPOCH 1 - PROGRESS: at 62.43% examples, 695986 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:53:27,393 : INFO : EPOCH 1 - PROGRESS: at 65.50% examples, 694613 words/s, in_qsize 90, out_qsize 3
# 2024-05-07 20:53:28,407 : INFO : EPOCH 1 - PROGRESS: at 68.89% examples, 697707 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 20:53:29,458 : INFO : EPOCH 1 - PROGRESS: at 72.27% examples, 699447 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:53:30,463 : INFO : EPOCH 1 - PROGRESS: at 75.54% examples, 701904 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:53:31,501 : INFO : EPOCH 1 - PROGRESS: at 78.67% examples, 701783 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 20:53:32,541 : INFO : EPOCH 1 - PROGRESS: at 82.15% examples, 704556 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:53:33,557 : INFO : EPOCH 1 - PROGRESS: at 85.35% examples, 705628 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:53:34,598 : INFO : EPOCH 1 - PROGRESS: at 88.58% examples, 706121 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:53:35,638 : INFO : EPOCH 1 - PROGRESS: at 91.95% examples, 707746 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 20:53:36,658 : INFO : EPOCH 1 - PROGRESS: at 95.16% examples, 707928 words/s, in_qsize 95, out_qsize 6
# 2024-05-07 20:53:37,661 : INFO : EPOCH 1 - PROGRESS: at 98.91% examples, 713013 words/s, in_qsize 24, out_qsize 5
# 2024-05-07 20:53:37,771 : INFO : EPOCH 1: training on 23279529 raw words (22951015 effective words) took 32.0s, 718298 effective words/s
# 2024-05-07 20:53:38,868 : INFO : EPOCH 2 - PROGRESS: at 2.07% examples, 444891 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:53:39,876 : INFO : EPOCH 2 - PROGRESS: at 5.70% examples, 635454 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:53:40,909 : INFO : EPOCH 2 - PROGRESS: at 8.74% examples, 651942 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:53:41,937 : INFO : EPOCH 2 - PROGRESS: at 12.21% examples, 679465 words/s, in_qsize 96, out_qsize 3
# 2024-05-07 20:53:42,956 : INFO : EPOCH 2 - PROGRESS: at 15.39% examples, 687965 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 20:53:43,986 : INFO : EPOCH 2 - PROGRESS: at 18.75% examples, 698483 words/s, in_qsize 96, out_qsize 6
# 2024-05-07 20:53:44,994 : INFO : EPOCH 2 - PROGRESS: at 22.10% examples, 706955 words/s, in_qsize 92, out_qsize 0
# 2024-05-07 20:53:46,001 : INFO : EPOCH 2 - PROGRESS: at 25.32% examples, 709971 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:53:47,033 : INFO : EPOCH 2 - PROGRESS: at 28.75% examples, 714408 words/s, in_qsize 94, out_qsize 2
# 2024-05-07 20:53:48,038 : INFO : EPOCH 2 - PROGRESS: at 32.01% examples, 718101 words/s, in_qsize 94, out_qsize 0
# 2024-05-07 20:53:49,049 : INFO : EPOCH 2 - PROGRESS: at 35.20% examples, 718180 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:53:50,250 : INFO : EPOCH 2 - PROGRESS: at 38.18% examples, 703319 words/s, in_qsize 91, out_qsize 12
# 2024-05-07 20:53:51,253 : INFO : EPOCH 2 - PROGRESS: at 41.62% examples, 709687 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:53:52,278 : INFO : EPOCH 2 - PROGRESS: at 44.33% examples, 702976 words/s, in_qsize 94, out_qsize 4
# 2024-05-07 20:53:53,307 : INFO : EPOCH 2 - PROGRESS: at 47.57% examples, 703014 words/s, in_qsize 94, out_qsize 2
# 2024-05-07 20:53:54,339 : INFO : EPOCH 2 - PROGRESS: at 50.87% examples, 704783 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:53:55,373 : INFO : EPOCH 2 - PROGRESS: at 54.24% examples, 706789 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 20:53:56,377 : INFO : EPOCH 2 - PROGRESS: at 57.37% examples, 708128 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:53:57,432 : INFO : EPOCH 2 - PROGRESS: at 60.79% examples, 709544 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 20:53:58,495 : INFO : EPOCH 2 - PROGRESS: at 64.07% examples, 708679 words/s, in_qsize 85, out_qsize 4
# 2024-05-07 20:53:59,500 : INFO : EPOCH 2 - PROGRESS: at 67.36% examples, 709803 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:54:00,522 : INFO : EPOCH 2 - PROGRESS: at 70.37% examples, 708461 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 20:54:01,576 : INFO : EPOCH 2 - PROGRESS: at 73.25% examples, 705074 words/s, in_qsize 95, out_qsize 6
# 2024-05-07 20:54:02,599 : INFO : EPOCH 2 - PROGRESS: at 76.57% examples, 707269 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:54:03,602 : INFO : EPOCH 2 - PROGRESS: at 79.67% examples, 707556 words/s, in_qsize 94, out_qsize 2
# 2024-05-07 20:54:04,680 : INFO : EPOCH 2 - PROGRESS: at 82.57% examples, 704000 words/s, in_qsize 96, out_qsize 12
# 2024-05-07 20:54:05,726 : INFO : EPOCH 2 - PROGRESS: at 85.86% examples, 705054 words/s, in_qsize 96, out_qsize 7
# 2024-05-07 20:54:06,825 : INFO : EPOCH 2 - PROGRESS: at 89.52% examples, 707430 words/s, in_qsize 91, out_qsize 6
# 2024-05-07 20:54:07,927 : INFO : EPOCH 2 - PROGRESS: at 92.79% examples, 706934 words/s, in_qsize 95, out_qsize 7
# 2024-05-07 20:54:08,947 : INFO : EPOCH 2 - PROGRESS: at 96.42% examples, 710571 words/s, in_qsize 84, out_qsize 1
# 2024-05-07 20:54:09,717 : INFO : EPOCH 2: training on 23279529 raw words (22951015 effective words) took 31.9s, 719071 effective words/s
# 2024-05-07 20:54:10,797 : INFO : EPOCH 3 - PROGRESS: at 2.17% examples, 480095 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:54:11,834 : INFO : EPOCH 3 - PROGRESS: at 5.50% examples, 608230 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:54:12,864 : INFO : EPOCH 3 - PROGRESS: at 8.53% examples, 634313 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 20:54:13,972 : INFO : EPOCH 3 - PROGRESS: at 11.69% examples, 637660 words/s, in_qsize 94, out_qsize 15
# 2024-05-07 20:54:15,089 : INFO : EPOCH 3 - PROGRESS: at 14.96% examples, 645594 words/s, in_qsize 95, out_qsize 12
# 2024-05-07 20:54:16,094 : INFO : EPOCH 3 - PROGRESS: at 18.41% examples, 668529 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:54:17,128 : INFO : EPOCH 3 - PROGRESS: at 21.39% examples, 666827 words/s, in_qsize 91, out_qsize 2
# 2024-05-07 20:54:18,140 : INFO : EPOCH 3 - PROGRESS: at 24.46% examples, 670527 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:54:19,144 : INFO : EPOCH 3 - PROGRESS: at 27.57% examples, 674116 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:54:20,173 : INFO : EPOCH 3 - PROGRESS: at 30.58% examples, 673484 words/s, in_qsize 91, out_qsize 4
# 2024-05-07 20:54:21,206 : INFO : EPOCH 3 - PROGRESS: at 33.69% examples, 674581 words/s, in_qsize 94, out_qsize 2
# 2024-05-07 20:54:22,219 : INFO : EPOCH 3 - PROGRESS: at 36.66% examples, 674701 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:54:23,249 : INFO : EPOCH 3 - PROGRESS: at 39.75% examples, 675617 words/s, in_qsize 96, out_qsize 2
# 2024-05-07 20:54:24,253 : INFO : EPOCH 3 - PROGRESS: at 42.66% examples, 674736 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:54:25,302 : INFO : EPOCH 3 - PROGRESS: at 45.59% examples, 672738 words/s, in_qsize 93, out_qsize 5
# 2024-05-07 20:54:26,313 : INFO : EPOCH 3 - PROGRESS: at 48.84% examples, 675581 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 20:54:27,349 : INFO : EPOCH 3 - PROGRESS: at 51.70% examples, 673204 words/s, in_qsize 94, out_qsize 5
# 2024-05-07 20:54:28,370 : INFO : EPOCH 3 - PROGRESS: at 54.74% examples, 673108 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:54:29,408 : INFO : EPOCH 3 - PROGRESS: at 57.77% examples, 673500 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 20:54:30,418 : INFO : EPOCH 3 - PROGRESS: at 60.97% examples, 675758 words/s, in_qsize 96, out_qsize 2
# 2024-05-07 20:54:31,433 : INFO : EPOCH 3 - PROGRESS: at 64.17% examples, 677210 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:54:32,481 : INFO : EPOCH 3 - PROGRESS: at 67.30% examples, 677074 words/s, in_qsize 94, out_qsize 4
# 2024-05-07 20:54:33,498 : INFO : EPOCH 3 - PROGRESS: at 70.64% examples, 680613 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:54:34,541 : INFO : EPOCH 3 - PROGRESS: at 73.62% examples, 679650 words/s, in_qsize 96, out_qsize 7
# 2024-05-07 20:54:35,585 : INFO : EPOCH 3 - PROGRESS: at 77.06% examples, 683231 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:54:36,647 : INFO : EPOCH 3 - PROGRESS: at 80.21% examples, 683321 words/s, in_qsize 96, out_qsize 5
# 2024-05-07 20:54:37,695 : INFO : EPOCH 3 - PROGRESS: at 83.76% examples, 686785 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:54:38,780 : INFO : EPOCH 3 - PROGRESS: at 86.90% examples, 686218 words/s, in_qsize 96, out_qsize 12
# 2024-05-07 20:54:39,810 : INFO : EPOCH 3 - PROGRESS: at 90.36% examples, 689794 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:54:40,845 : INFO : EPOCH 3 - PROGRESS: at 93.75% examples, 692024 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:54:41,890 : INFO : EPOCH 3 - PROGRESS: at 97.12% examples, 693647 words/s, in_qsize 65, out_qsize 3
# 2024-05-07 20:54:42,429 : INFO : EPOCH 3: training on 23279529 raw words (22951015 effective words) took 32.7s, 702209 effective words/s
# 2024-05-07 20:54:43,482 : INFO : EPOCH 4 - PROGRESS: at 2.03% examples, 455172 words/s, in_qsize 96, out_qsize 2
# 2024-05-07 20:54:44,491 : INFO : EPOCH 4 - PROGRESS: at 5.40% examples, 615979 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:54:45,553 : INFO : EPOCH 4 - PROGRESS: at 8.37% examples, 626657 words/s, in_qsize 93, out_qsize 6
# 2024-05-07 20:54:46,616 : INFO : EPOCH 4 - PROGRESS: at 12.08% examples, 669152 words/s, in_qsize 96, out_qsize 3
# 2024-05-07 20:54:47,616 : INFO : EPOCH 4 - PROGRESS: at 15.57% examples, 695407 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:54:48,677 : INFO : EPOCH 4 - PROGRESS: at 18.77% examples, 694811 words/s, in_qsize 96, out_qsize 3
# 2024-05-07 20:54:49,684 : INFO : EPOCH 4 - PROGRESS: at 22.22% examples, 707901 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:54:50,744 : INFO : EPOCH 4 - PROGRESS: at 24.97% examples, 693421 words/s, in_qsize 90, out_qsize 7
# 2024-05-07 20:54:51,775 : INFO : EPOCH 4 - PROGRESS: at 28.50% examples, 701833 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 20:54:52,825 : INFO : EPOCH 4 - PROGRESS: at 31.72% examples, 702653 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 20:54:53,825 : INFO : EPOCH 4 - PROGRESS: at 34.79% examples, 702964 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:54:54,834 : INFO : EPOCH 4 - PROGRESS: at 37.52% examples, 695774 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:54:55,930 : INFO : EPOCH 4 - PROGRESS: at 40.55% examples, 690893 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 20:54:57,057 : INFO : EPOCH 4 - PROGRESS: at 43.25% examples, 679919 words/s, in_qsize 95, out_qsize 15
# 2024-05-07 20:54:58,084 : INFO : EPOCH 4 - PROGRESS: at 46.73% examples, 685937 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:54:59,102 : INFO : EPOCH 4 - PROGRESS: at 49.78% examples, 685266 words/s, in_qsize 88, out_qsize 0
# 2024-05-07 20:55:00,310 : INFO : EPOCH 4 - PROGRESS: at 52.83% examples, 677931 words/s, in_qsize 95, out_qsize 15
# 2024-05-07 20:55:01,322 : INFO : EPOCH 4 - PROGRESS: at 56.56% examples, 687147 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:55:02,333 : INFO : EPOCH 4 - PROGRESS: at 59.51% examples, 686294 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:55:03,361 : INFO : EPOCH 4 - PROGRESS: at 62.54% examples, 684999 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 20:55:04,394 : INFO : EPOCH 4 - PROGRESS: at 65.84% examples, 686715 words/s, in_qsize 92, out_qsize 0
# 2024-05-07 20:55:05,422 : INFO : EPOCH 4 - PROGRESS: at 68.77% examples, 685049 words/s, in_qsize 95, out_qsize 3
# 2024-05-07 20:55:06,442 : INFO : EPOCH 4 - PROGRESS: at 72.28% examples, 689787 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 20:55:07,457 : INFO : EPOCH 4 - PROGRESS: at 75.53% examples, 691973 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 20:55:08,494 : INFO : EPOCH 4 - PROGRESS: at 78.72% examples, 692633 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:55:09,506 : INFO : EPOCH 4 - PROGRESS: at 81.89% examples, 693970 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:55:10,666 : INFO : EPOCH 4 - PROGRESS: at 85.23% examples, 692860 words/s, in_qsize 94, out_qsize 10
# 2024-05-07 20:55:11,691 : INFO : EPOCH 4 - PROGRESS: at 88.71% examples, 696138 words/s, in_qsize 94, out_qsize 2
# 2024-05-07 20:55:12,719 : INFO : EPOCH 4 - PROGRESS: at 92.03% examples, 698060 words/s, in_qsize 95, out_qsize 5
# 2024-05-07 20:55:13,740 : INFO : EPOCH 4 - PROGRESS: at 95.60% examples, 701349 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:55:14,756 : INFO : EPOCH 4 - PROGRESS: at 99.14% examples, 704763 words/s, in_qsize 17, out_qsize 7
# 2024-05-07 20:55:14,810 : INFO : EPOCH 4: training on 23279529 raw words (22951015 effective words) took 32.4s, 709435 effective words/s
# 2024-05-07 20:55:15,852 : INFO : EPOCH 5 - PROGRESS: at 2.39% examples, 546234 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:55:16,894 : INFO : EPOCH 5 - PROGRESS: at 5.36% examples, 604629 words/s, in_qsize 96, out_qsize 4
# 2024-05-07 20:55:17,905 : INFO : EPOCH 5 - PROGRESS: at 9.08% examples, 683284 words/s, in_qsize 96, out_qsize 3
# 2024-05-07 20:55:18,925 : INFO : EPOCH 5 - PROGRESS: at 12.34% examples, 695109 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:55:19,964 : INFO : EPOCH 5 - PROGRESS: at 15.89% examples, 714993 words/s, in_qsize 89, out_qsize 6
# 2024-05-07 20:55:20,991 : INFO : EPOCH 5 - PROGRESS: at 19.63% examples, 733925 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:55:22,018 : INFO : EPOCH 5 - PROGRESS: at 23.09% examples, 740915 words/s, in_qsize 94, out_qsize 2
# 2024-05-07 20:55:23,031 : INFO : EPOCH 5 - PROGRESS: at 26.60% examples, 746214 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:55:24,039 : INFO : EPOCH 5 - PROGRESS: at 29.36% examples, 732758 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:55:25,065 : INFO : EPOCH 5 - PROGRESS: at 32.40% examples, 727527 words/s, in_qsize 96, out_qsize 3
# 2024-05-07 20:55:26,091 : INFO : EPOCH 5 - PROGRESS: at 35.61% examples, 726506 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:55:27,096 : INFO : EPOCH 5 - PROGRESS: at 38.75% examples, 725550 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:55:28,144 : INFO : EPOCH 5 - PROGRESS: at 41.81% examples, 721199 words/s, in_qsize 96, out_qsize 3
# 2024-05-07 20:55:29,162 : INFO : EPOCH 5 - PROGRESS: at 45.28% examples, 725959 words/s, in_qsize 95, out_qsize 4
# 2024-05-07 20:55:30,213 : INFO : EPOCH 5 - PROGRESS: at 48.26% examples, 719169 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 20:55:31,214 : INFO : EPOCH 5 - PROGRESS: at 51.51% examples, 720711 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:55:32,224 : INFO : EPOCH 5 - PROGRESS: at 54.40% examples, 716665 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:55:33,226 : INFO : EPOCH 5 - PROGRESS: at 57.30% examples, 714426 words/s, in_qsize 93, out_qsize 0
# 2024-05-07 20:55:34,269 : INFO : EPOCH 5 - PROGRESS: at 60.23% examples, 710450 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:55:35,278 : INFO : EPOCH 5 - PROGRESS: at 63.17% examples, 707666 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:55:36,305 : INFO : EPOCH 5 - PROGRESS: at 66.33% examples, 706693 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 20:55:37,345 : INFO : EPOCH 5 - PROGRESS: at 69.16% examples, 703233 words/s, in_qsize 96, out_qsize 10
# 2024-05-07 20:55:38,361 : INFO : EPOCH 5 - PROGRESS: at 72.59% examples, 706166 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 20:55:39,369 : INFO : EPOCH 5 - PROGRESS: at 75.82% examples, 707931 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:55:40,389 : INFO : EPOCH 5 - PROGRESS: at 78.86% examples, 706949 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 20:55:41,391 : INFO : EPOCH 5 - PROGRESS: at 82.03% examples, 708005 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:55:42,418 : INFO : EPOCH 5 - PROGRESS: at 85.30% examples, 709030 words/s, in_qsize 92, out_qsize 0
# 2024-05-07 20:55:43,441 : INFO : EPOCH 5 - PROGRESS: at 88.42% examples, 709142 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 20:55:44,481 : INFO : EPOCH 5 - PROGRESS: at 91.53% examples, 708745 words/s, in_qsize 94, out_qsize 4
# 2024-05-07 20:55:45,483 : INFO : EPOCH 5 - PROGRESS: at 94.55% examples, 708013 words/s, in_qsize 95, out_qsize 10
# 2024-05-07 20:55:46,487 : INFO : EPOCH 5 - PROGRESS: at 98.08% examples, 711578 words/s, in_qsize 44, out_qsize 3
# 2024-05-07 20:55:46,754 : INFO : EPOCH 5: training on 23279529 raw words (22951015 effective words) took 31.9s, 719134 effective words/s
# 2024-05-07 20:55:47,815 : INFO : EPOCH 6 - PROGRESS: at 1.99% examples, 442161 words/s, in_qsize 96, out_qsize 3
# 2024-05-07 20:55:48,818 : INFO : EPOCH 6 - PROGRESS: at 5.28% examples, 601184 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:55:49,854 : INFO : EPOCH 6 - PROGRESS: at 8.45% examples, 638397 words/s, in_qsize 96, out_qsize 3
# 2024-05-07 20:55:50,856 : INFO : EPOCH 6 - PROGRESS: at 11.72% examples, 661952 words/s, in_qsize 93, out_qsize 3
# 2024-05-07 20:55:51,938 : INFO : EPOCH 6 - PROGRESS: at 14.89% examples, 665840 words/s, in_qsize 86, out_qsize 7
# 2024-05-07 20:55:53,030 : INFO : EPOCH 6 - PROGRESS: at 17.99% examples, 664238 words/s, in_qsize 93, out_qsize 6
# 2024-05-07 20:55:54,041 : INFO : EPOCH 6 - PROGRESS: at 21.17% examples, 671722 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 20:55:55,043 : INFO : EPOCH 6 - PROGRESS: at 23.87% examples, 665237 words/s, in_qsize 96, out_qsize 6
# 2024-05-07 20:55:56,064 : INFO : EPOCH 6 - PROGRESS: at 26.78% examples, 662920 words/s, in_qsize 96, out_qsize 3
# 2024-05-07 20:55:57,080 : INFO : EPOCH 6 - PROGRESS: at 29.64% examples, 660396 words/s, in_qsize 96, out_qsize 4
# 2024-05-07 20:55:58,080 : INFO : EPOCH 6 - PROGRESS: at 32.50% examples, 660346 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:55:59,107 : INFO : EPOCH 6 - PROGRESS: at 35.57% examples, 662559 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:56:00,155 : INFO : EPOCH 6 - PROGRESS: at 38.52% examples, 660711 words/s, in_qsize 87, out_qsize 8
# 2024-05-07 20:56:01,188 : INFO : EPOCH 6 - PROGRESS: at 41.69% examples, 664315 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:56:02,236 : INFO : EPOCH 6 - PROGRESS: at 44.91% examples, 667344 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:56:03,249 : INFO : EPOCH 6 - PROGRESS: at 48.18% examples, 670389 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:56:04,256 : INFO : EPOCH 6 - PROGRESS: at 51.46% examples, 674903 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:56:05,285 : INFO : EPOCH 6 - PROGRESS: at 54.66% examples, 676612 words/s, in_qsize 94, out_qsize 0
# 2024-05-07 20:56:06,289 : INFO : EPOCH 6 - PROGRESS: at 57.68% examples, 677947 words/s, in_qsize 96, out_qsize 4
# 2024-05-07 20:56:07,332 : INFO : EPOCH 6 - PROGRESS: at 61.11% examples, 681275 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:56:08,335 : INFO : EPOCH 6 - PROGRESS: at 64.17% examples, 681441 words/s, in_qsize 91, out_qsize 2
# 2024-05-07 20:56:09,380 : INFO : EPOCH 6 - PROGRESS: at 67.61% examples, 684244 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:56:10,405 : INFO : EPOCH 6 - PROGRESS: at 70.81% examples, 685648 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:56:11,413 : INFO : EPOCH 6 - PROGRESS: at 74.11% examples, 688976 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:56:12,430 : INFO : EPOCH 6 - PROGRESS: at 77.38% examples, 691041 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:56:13,452 : INFO : EPOCH 6 - PROGRESS: at 80.66% examples, 693314 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:56:14,492 : INFO : EPOCH 6 - PROGRESS: at 83.99% examples, 694904 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 20:56:15,501 : INFO : EPOCH 6 - PROGRESS: at 87.39% examples, 697826 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:56:16,506 : INFO : EPOCH 6 - PROGRESS: at 90.42% examples, 698367 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 20:56:17,524 : INFO : EPOCH 6 - PROGRESS: at 93.59% examples, 698859 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:56:18,565 : INFO : EPOCH 6 - PROGRESS: at 97.11% examples, 701596 words/s, in_qsize 64, out_qsize 4
# 2024-05-07 20:56:19,094 : INFO : EPOCH 6: training on 23279529 raw words (22951015 effective words) took 32.3s, 710335 effective words/s
# 2024-05-07 20:56:20,202 : INFO : EPOCH 7 - PROGRESS: at 2.35% examples, 534273 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 20:56:21,212 : INFO : EPOCH 7 - PROGRESS: at 5.90% examples, 674421 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:56:22,253 : INFO : EPOCH 7 - PROGRESS: at 9.00% examples, 679118 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 20:56:23,282 : INFO : EPOCH 7 - PROGRESS: at 12.38% examples, 695268 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:56:24,297 : INFO : EPOCH 7 - PROGRESS: at 15.49% examples, 697558 words/s, in_qsize 95, out_qsize 5
# 2024-05-07 20:56:25,317 : INFO : EPOCH 7 - PROGRESS: at 18.63% examples, 699971 words/s, in_qsize 95, out_qsize 4
# 2024-05-07 20:56:26,371 : INFO : EPOCH 7 - PROGRESS: at 22.21% examples, 711670 words/s, in_qsize 93, out_qsize 6
# 2024-05-07 20:56:27,404 : INFO : EPOCH 7 - PROGRESS: at 25.49% examples, 713127 words/s, in_qsize 96, out_qsize 2
# 2024-05-07 20:56:28,411 : INFO : EPOCH 7 - PROGRESS: at 28.87% examples, 718019 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 20:56:29,454 : INFO : EPOCH 7 - PROGRESS: at 32.19% examples, 719637 words/s, in_qsize 90, out_qsize 5
# 2024-05-07 20:56:30,463 : INFO : EPOCH 7 - PROGRESS: at 35.73% examples, 727313 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:56:31,470 : INFO : EPOCH 7 - PROGRESS: at 39.05% examples, 729340 words/s, in_qsize 94, out_qsize 3
# 2024-05-07 20:56:32,478 : INFO : EPOCH 7 - PROGRESS: at 42.19% examples, 728257 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:56:33,483 : INFO : EPOCH 7 - PROGRESS: at 44.99% examples, 722500 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:56:34,514 : INFO : EPOCH 7 - PROGRESS: at 47.95% examples, 716783 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:56:35,547 : INFO : EPOCH 7 - PROGRESS: at 50.63% examples, 708801 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 20:56:36,582 : INFO : EPOCH 7 - PROGRESS: at 53.37% examples, 702741 words/s, in_qsize 94, out_qsize 6
# 2024-05-07 20:56:37,618 : INFO : EPOCH 7 - PROGRESS: at 56.69% examples, 704777 words/s, in_qsize 96, out_qsize 2
# 2024-05-07 20:56:38,665 : INFO : EPOCH 7 - PROGRESS: at 59.60% examples, 701130 words/s, in_qsize 96, out_qsize 7
# 2024-05-07 20:56:39,672 : INFO : EPOCH 7 - PROGRESS: at 63.01% examples, 704031 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 20:56:40,678 : INFO : EPOCH 7 - PROGRESS: at 66.00% examples, 702613 words/s, in_qsize 95, out_qsize 3
# 2024-05-07 20:56:41,689 : INFO : EPOCH 7 - PROGRESS: at 69.25% examples, 704112 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:56:42,758 : INFO : EPOCH 7 - PROGRESS: at 71.88% examples, 697674 words/s, in_qsize 96, out_qsize 9
# 2024-05-07 20:56:43,767 : INFO : EPOCH 7 - PROGRESS: at 75.07% examples, 699332 words/s, in_qsize 95, out_qsize 4
# 2024-05-07 20:56:44,802 : INFO : EPOCH 7 - PROGRESS: at 78.24% examples, 699774 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:56:45,808 : INFO : EPOCH 7 - PROGRESS: at 81.57% examples, 702077 words/s, in_qsize 95, out_qsize 4
# 2024-05-07 20:56:46,816 : INFO : EPOCH 7 - PROGRESS: at 84.77% examples, 703434 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 20:56:47,836 : INFO : EPOCH 7 - PROGRESS: at 87.96% examples, 704170 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:56:48,842 : INFO : EPOCH 7 - PROGRESS: at 91.09% examples, 705061 words/s, in_qsize 94, out_qsize 0
# 2024-05-07 20:56:49,876 : INFO : EPOCH 7 - PROGRESS: at 94.14% examples, 704059 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 20:56:50,878 : INFO : EPOCH 7 - PROGRESS: at 97.43% examples, 705927 words/s, in_qsize 59, out_qsize 1
# 2024-05-07 20:56:51,336 : INFO : EPOCH 7: training on 23279529 raw words (22951015 effective words) took 32.2s, 713825 effective words/s
# 2024-05-07 20:56:52,379 : INFO : EPOCH 8 - PROGRESS: at 1.67% examples, 386244 words/s, in_qsize 94, out_qsize 11
# 2024-05-07 20:56:53,436 : INFO : EPOCH 8 - PROGRESS: at 5.36% examples, 602527 words/s, in_qsize 96, out_qsize 2
# 2024-05-07 20:56:54,444 : INFO : EPOCH 8 - PROGRESS: at 8.75% examples, 660405 words/s, in_qsize 93, out_qsize 0
# 2024-05-07 20:56:55,446 : INFO : EPOCH 8 - PROGRESS: at 11.89% examples, 673756 words/s, in_qsize 91, out_qsize 2
# 2024-05-07 20:56:56,458 : INFO : EPOCH 8 - PROGRESS: at 15.09% examples, 684374 words/s, in_qsize 94, out_qsize 2
# 2024-05-07 20:56:57,472 : INFO : EPOCH 8 - PROGRESS: at 18.30% examples, 691247 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:56:58,493 : INFO : EPOCH 8 - PROGRESS: at 21.38% examples, 691530 words/s, in_qsize 92, out_qsize 4
# 2024-05-07 20:56:59,514 : INFO : EPOCH 8 - PROGRESS: at 24.64% examples, 696273 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 20:57:00,586 : INFO : EPOCH 8 - PROGRESS: at 27.74% examples, 692071 words/s, in_qsize 95, out_qsize 6
# 2024-05-07 20:57:01,624 : INFO : EPOCH 8 - PROGRESS: at 30.47% examples, 682230 words/s, in_qsize 96, out_qsize 4
# 2024-05-07 20:57:02,669 : INFO : EPOCH 8 - PROGRESS: at 33.76% examples, 686115 words/s, in_qsize 95, out_qsize 4
# 2024-05-07 20:57:03,692 : INFO : EPOCH 8 - PROGRESS: at 36.69% examples, 683336 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:57:04,720 : INFO : EPOCH 8 - PROGRESS: at 39.69% examples, 682886 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:57:05,727 : INFO : EPOCH 8 - PROGRESS: at 42.68% examples, 682685 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:57:06,751 : INFO : EPOCH 8 - PROGRESS: at 45.56% examples, 679969 words/s, in_qsize 90, out_qsize 2
# 2024-05-07 20:57:07,775 : INFO : EPOCH 8 - PROGRESS: at 48.71% examples, 680658 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:57:08,782 : INFO : EPOCH 8 - PROGRESS: at 51.71% examples, 680747 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:57:09,792 : INFO : EPOCH 8 - PROGRESS: at 54.80% examples, 681245 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:57:10,874 : INFO : EPOCH 8 - PROGRESS: at 57.80% examples, 679638 words/s, in_qsize 96, out_qsize 3
# 2024-05-07 20:57:11,877 : INFO : EPOCH 8 - PROGRESS: at 60.68% examples, 678562 words/s, in_qsize 96, out_qsize 3
# 2024-05-07 20:57:12,892 : INFO : EPOCH 8 - PROGRESS: at 63.79% examples, 678496 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:57:13,899 : INFO : EPOCH 8 - PROGRESS: at 66.86% examples, 679109 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:57:14,936 : INFO : EPOCH 8 - PROGRESS: at 69.72% examples, 677075 words/s, in_qsize 96, out_qsize 3
# 2024-05-07 20:57:15,975 : INFO : EPOCH 8 - PROGRESS: at 72.92% examples, 678328 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:57:17,006 : INFO : EPOCH 8 - PROGRESS: at 76.16% examples, 680500 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 20:57:18,009 : INFO : EPOCH 8 - PROGRESS: at 79.21% examples, 681414 words/s, in_qsize 88, out_qsize 7
# 2024-05-07 20:57:19,022 : INFO : EPOCH 8 - PROGRESS: at 82.45% examples, 683488 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:57:20,039 : INFO : EPOCH 8 - PROGRESS: at 85.35% examples, 682829 words/s, in_qsize 96, out_qsize 5
# 2024-05-07 20:57:21,066 : INFO : EPOCH 8 - PROGRESS: at 88.56% examples, 684114 words/s, in_qsize 96, out_qsize 6
# 2024-05-07 20:57:22,157 : INFO : EPOCH 8 - PROGRESS: at 91.90% examples, 685277 words/s, in_qsize 95, out_qsize 4
# 2024-05-07 20:57:23,199 : INFO : EPOCH 8 - PROGRESS: at 95.33% examples, 687532 words/s, in_qsize 92, out_qsize 3
# 2024-05-07 20:57:24,207 : INFO : EPOCH 8 - PROGRESS: at 98.81% examples, 690922 words/s, in_qsize 27, out_qsize 3
# 2024-05-07 20:57:24,291 : INFO : EPOCH 8: training on 23279529 raw words (22951015 effective words) took 32.9s, 697246 effective words/s
# 2024-05-07 20:57:25,416 : INFO : EPOCH 9 - PROGRESS: at 2.15% examples, 451321 words/s, in_qsize 95, out_qsize 4
# 2024-05-07 20:57:26,457 : INFO : EPOCH 9 - PROGRESS: at 5.67% examples, 612848 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:57:27,481 : INFO : EPOCH 9 - PROGRESS: at 8.81% examples, 647101 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 20:57:28,506 : INFO : EPOCH 9 - PROGRESS: at 12.24% examples, 673865 words/s, in_qsize 96, out_qsize 2
# 2024-05-07 20:57:29,547 : INFO : EPOCH 9 - PROGRESS: at 15.26% examples, 673080 words/s, in_qsize 96, out_qsize 4
# 2024-05-07 20:57:30,554 : INFO : EPOCH 9 - PROGRESS: at 18.66% examples, 690050 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:57:31,578 : INFO : EPOCH 9 - PROGRESS: at 21.42% examples, 679465 words/s, in_qsize 96, out_qsize 10
# 2024-05-07 20:57:32,623 : INFO : EPOCH 9 - PROGRESS: at 24.83% examples, 688444 words/s, in_qsize 91, out_qsize 3
# 2024-05-07 20:57:33,626 : INFO : EPOCH 9 - PROGRESS: at 27.77% examples, 685952 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:57:34,631 : INFO : EPOCH 9 - PROGRESS: at 30.89% examples, 687610 words/s, in_qsize 96, out_qsize 2
# 2024-05-07 20:57:35,654 : INFO : EPOCH 9 - PROGRESS: at 34.01% examples, 688832 words/s, in_qsize 96, out_qsize 4
# 2024-05-07 20:57:36,666 : INFO : EPOCH 9 - PROGRESS: at 37.32% examples, 693474 words/s, in_qsize 92, out_qsize 0
# 2024-05-07 20:57:37,680 : INFO : EPOCH 9 - PROGRESS: at 40.19% examples, 690862 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:57:38,694 : INFO : EPOCH 9 - PROGRESS: at 43.07% examples, 687801 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:57:39,700 : INFO : EPOCH 9 - PROGRESS: at 45.75% examples, 682929 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:57:40,714 : INFO : EPOCH 9 - PROGRESS: at 48.68% examples, 680364 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:57:41,727 : INFO : EPOCH 9 - PROGRESS: at 51.96% examples, 684099 words/s, in_qsize 89, out_qsize 2
# 2024-05-07 20:57:42,729 : INFO : EPOCH 9 - PROGRESS: at 54.81% examples, 681539 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:57:43,800 : INFO : EPOCH 9 - PROGRESS: at 57.56% examples, 677335 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 20:57:44,823 : INFO : EPOCH 9 - PROGRESS: at 60.83% examples, 679909 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:57:45,905 : INFO : EPOCH 9 - PROGRESS: at 64.01% examples, 678575 words/s, in_qsize 92, out_qsize 3
# 2024-05-07 20:57:46,928 : INFO : EPOCH 9 - PROGRESS: at 67.46% examples, 682560 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:57:47,930 : INFO : EPOCH 9 - PROGRESS: at 70.43% examples, 682642 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:57:48,934 : INFO : EPOCH 9 - PROGRESS: at 73.37% examples, 682273 words/s, in_qsize 95, out_qsize 3
# 2024-05-07 20:57:49,950 : INFO : EPOCH 9 - PROGRESS: at 76.85% examples, 686574 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:57:50,960 : INFO : EPOCH 9 - PROGRESS: at 79.95% examples, 687840 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:57:51,965 : INFO : EPOCH 9 - PROGRESS: at 83.19% examples, 689833 words/s, in_qsize 94, out_qsize 0
# 2024-05-07 20:57:52,967 : INFO : EPOCH 9 - PROGRESS: at 86.41% examples, 691749 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:57:53,984 : INFO : EPOCH 9 - PROGRESS: at 89.75% examples, 694206 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:57:55,014 : INFO : EPOCH 9 - PROGRESS: at 92.87% examples, 694552 words/s, in_qsize 91, out_qsize 5
# 2024-05-07 20:57:56,032 : INFO : EPOCH 9 - PROGRESS: at 96.19% examples, 696115 words/s, in_qsize 90, out_qsize 1
# 2024-05-07 20:57:56,886 : INFO : EPOCH 9: training on 23279529 raw words (22951015 effective words) took 32.6s, 704743 effective words/s
# 2024-05-07 20:57:57,916 : INFO : EPOCH 10 - PROGRESS: at 2.11% examples, 484979 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:57:58,957 : INFO : EPOCH 10 - PROGRESS: at 5.41% examples, 613363 words/s, in_qsize 92, out_qsize 4
# 2024-05-07 20:57:59,967 : INFO : EPOCH 10 - PROGRESS: at 8.58% examples, 651597 words/s, in_qsize 90, out_qsize 7
# 2024-05-07 20:58:00,994 : INFO : EPOCH 10 - PROGRESS: at 11.84% examples, 667855 words/s, in_qsize 93, out_qsize 4
# 2024-05-07 20:58:02,020 : INFO : EPOCH 10 - PROGRESS: at 15.26% examples, 689311 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:58:03,074 : INFO : EPOCH 10 - PROGRESS: at 18.43% examples, 689116 words/s, in_qsize 96, out_qsize 4
# 2024-05-07 20:58:04,086 : INFO : EPOCH 10 - PROGRESS: at 21.43% examples, 687801 words/s, in_qsize 95, out_qsize 6
# 2024-05-07 20:58:05,268 : INFO : EPOCH 10 - PROGRESS: at 24.55% examples, 676195 words/s, in_qsize 96, out_qsize 17
# 2024-05-07 20:58:06,307 : INFO : EPOCH 10 - PROGRESS: at 27.87% examples, 681860 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:58:07,317 : INFO : EPOCH 10 - PROGRESS: at 30.83% examples, 680619 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:58:08,324 : INFO : EPOCH 10 - PROGRESS: at 33.78% examples, 679305 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:58:09,336 : INFO : EPOCH 10 - PROGRESS: at 36.83% examples, 680799 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:58:10,352 : INFO : EPOCH 10 - PROGRESS: at 39.58% examples, 676195 words/s, in_qsize 95, out_qsize 3
# 2024-05-07 20:58:11,470 : INFO : EPOCH 10 - PROGRESS: at 42.65% examples, 672626 words/s, in_qsize 96, out_qsize 9
# 2024-05-07 20:58:12,508 : INFO : EPOCH 10 - PROGRESS: at 45.82% examples, 674885 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 20:58:13,629 : INFO : EPOCH 10 - PROGRESS: at 48.84% examples, 669652 words/s, in_qsize 94, out_qsize 5
# 2024-05-07 20:58:14,631 : INFO : EPOCH 10 - PROGRESS: at 51.92% examples, 671637 words/s, in_qsize 96, out_qsize 2
# 2024-05-07 20:58:15,666 : INFO : EPOCH 10 - PROGRESS: at 55.01% examples, 671744 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:58:16,718 : INFO : EPOCH 10 - PROGRESS: at 57.95% examples, 670710 words/s, in_qsize 96, out_qsize 7
# 2024-05-07 20:58:17,723 : INFO : EPOCH 10 - PROGRESS: at 61.32% examples, 675115 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:58:18,773 : INFO : EPOCH 10 - PROGRESS: at 64.36% examples, 673716 words/s, in_qsize 93, out_qsize 5
# 2024-05-07 20:58:19,806 : INFO : EPOCH 10 - PROGRESS: at 67.81% examples, 677581 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:58:20,836 : INFO : EPOCH 10 - PROGRESS: at 71.04% examples, 679470 words/s, in_qsize 96, out_qsize 4
# 2024-05-07 20:58:21,852 : INFO : EPOCH 10 - PROGRESS: at 74.08% examples, 680078 words/s, in_qsize 92, out_qsize 3
# 2024-05-07 20:58:22,873 : INFO : EPOCH 10 - PROGRESS: at 77.09% examples, 680529 words/s, in_qsize 96, out_qsize 3
# 2024-05-07 20:58:23,890 : INFO : EPOCH 10 - PROGRESS: at 80.58% examples, 684707 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:58:24,903 : INFO : EPOCH 10 - PROGRESS: at 83.78% examples, 686217 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:58:25,939 : INFO : EPOCH 10 - PROGRESS: at 87.00% examples, 687457 words/s, in_qsize 95, out_qsize 4
# 2024-05-07 20:58:26,945 : INFO : EPOCH 10 - PROGRESS: at 90.51% examples, 691858 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:58:27,953 : INFO : EPOCH 10 - PROGRESS: at 93.56% examples, 692143 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:58:28,970 : INFO : EPOCH 10 - PROGRESS: at 96.95% examples, 694382 words/s, in_qsize 72, out_qsize 0
# 2024-05-07 20:58:29,616 : INFO : EPOCH 10: training on 23279529 raw words (22951015 effective words) took 32.7s, 701855 effective words/s
# 2024-05-07 20:58:30,644 : INFO : EPOCH 11 - PROGRESS: at 2.08% examples, 484207 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:58:31,685 : INFO : EPOCH 11 - PROGRESS: at 5.28% examples, 598356 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:58:32,710 : INFO : EPOCH 11 - PROGRESS: at 8.65% examples, 654287 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:58:33,745 : INFO : EPOCH 11 - PROGRESS: at 11.74% examples, 659008 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 20:58:34,805 : INFO : EPOCH 11 - PROGRESS: at 15.01% examples, 670314 words/s, in_qsize 95, out_qsize 4
# 2024-05-07 20:58:35,849 : INFO : EPOCH 11 - PROGRESS: at 18.44% examples, 685286 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:58:36,860 : INFO : EPOCH 11 - PROGRESS: at 21.60% examples, 688683 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:58:37,869 : INFO : EPOCH 11 - PROGRESS: at 24.75% examples, 692403 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:58:38,923 : INFO : EPOCH 11 - PROGRESS: at 27.90% examples, 690878 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 20:58:39,950 : INFO : EPOCH 11 - PROGRESS: at 30.79% examples, 685999 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 20:58:40,969 : INFO : EPOCH 11 - PROGRESS: at 34.08% examples, 690185 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:58:42,001 : INFO : EPOCH 11 - PROGRESS: at 37.13% examples, 689641 words/s, in_qsize 90, out_qsize 5
# 2024-05-07 20:58:43,048 : INFO : EPOCH 11 - PROGRESS: at 40.23% examples, 689171 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:58:44,071 : INFO : EPOCH 11 - PROGRESS: at 42.99% examples, 683822 words/s, in_qsize 95, out_qsize 6
# 2024-05-07 20:58:45,081 : INFO : EPOCH 11 - PROGRESS: at 46.01% examples, 684123 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:58:46,103 : INFO : EPOCH 11 - PROGRESS: at 49.16% examples, 684598 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:58:47,138 : INFO : EPOCH 11 - PROGRESS: at 52.27% examples, 684515 words/s, in_qsize 95, out_qsize 3
# 2024-05-07 20:58:48,140 : INFO : EPOCH 11 - PROGRESS: at 55.56% examples, 688135 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:58:49,182 : INFO : EPOCH 11 - PROGRESS: at 58.63% examples, 687650 words/s, in_qsize 92, out_qsize 3
# 2024-05-07 20:58:50,188 : INFO : EPOCH 11 - PROGRESS: at 61.62% examples, 686967 words/s, in_qsize 89, out_qsize 3
# 2024-05-07 20:58:51,202 : INFO : EPOCH 11 - PROGRESS: at 65.11% examples, 690991 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:58:52,255 : INFO : EPOCH 11 - PROGRESS: at 68.44% examples, 692687 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 20:58:53,277 : INFO : EPOCH 11 - PROGRESS: at 71.64% examples, 693390 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:58:54,287 : INFO : EPOCH 11 - PROGRESS: at 74.49% examples, 692040 words/s, in_qsize 95, out_qsize 10
# 2024-05-07 20:58:55,324 : INFO : EPOCH 11 - PROGRESS: at 78.05% examples, 696096 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 20:58:56,325 : INFO : EPOCH 11 - PROGRESS: at 81.24% examples, 697984 words/s, in_qsize 96, out_qsize 4
# 2024-05-07 20:58:57,332 : INFO : EPOCH 11 - PROGRESS: at 84.60% examples, 700557 words/s, in_qsize 92, out_qsize 3
# 2024-05-07 20:58:58,352 : INFO : EPOCH 11 - PROGRESS: at 87.68% examples, 700377 words/s, in_qsize 89, out_qsize 6
# 2024-05-07 20:58:59,387 : INFO : EPOCH 11 - PROGRESS: at 91.15% examples, 703348 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 20:59:00,395 : INFO : EPOCH 11 - PROGRESS: at 94.34% examples, 703913 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 20:59:01,409 : INFO : EPOCH 11 - PROGRESS: at 97.58% examples, 705531 words/s, in_qsize 55, out_qsize 1
# 2024-05-07 20:59:01,804 : INFO : EPOCH 11: training on 23279529 raw words (22951015 effective words) took 32.2s, 713596 effective words/s
# 2024-05-07 20:59:02,847 : INFO : EPOCH 12 - PROGRESS: at 2.07% examples, 468953 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:59:03,855 : INFO : EPOCH 12 - PROGRESS: at 5.47% examples, 628390 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:59:04,898 : INFO : EPOCH 12 - PROGRESS: at 8.70% examples, 658132 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:59:05,904 : INFO : EPOCH 12 - PROGRESS: at 12.04% examples, 681066 words/s, in_qsize 92, out_qsize 2
# 2024-05-07 20:59:06,921 : INFO : EPOCH 12 - PROGRESS: at 15.23% examples, 689638 words/s, in_qsize 96, out_qsize 2
# 2024-05-07 20:59:07,956 : INFO : EPOCH 12 - PROGRESS: at 18.51% examples, 696258 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:59:08,960 : INFO : EPOCH 12 - PROGRESS: at 21.93% examples, 708249 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:59:09,976 : INFO : EPOCH 12 - PROGRESS: at 25.15% examples, 710325 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:59:10,987 : INFO : EPOCH 12 - PROGRESS: at 28.14% examples, 705849 words/s, in_qsize 96, out_qsize 2
# 2024-05-07 20:59:11,998 : INFO : EPOCH 12 - PROGRESS: at 31.46% examples, 710914 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:59:13,005 : INFO : EPOCH 12 - PROGRESS: at 34.49% examples, 708456 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:59:14,021 : INFO : EPOCH 12 - PROGRESS: at 37.38% examples, 703310 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:59:15,046 : INFO : EPOCH 12 - PROGRESS: at 40.42% examples, 702148 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:59:16,060 : INFO : EPOCH 12 - PROGRESS: at 43.51% examples, 702363 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 20:59:17,084 : INFO : EPOCH 12 - PROGRESS: at 46.81% examples, 703999 words/s, in_qsize 96, out_qsize 4
# 2024-05-07 20:59:18,092 : INFO : EPOCH 12 - PROGRESS: at 50.11% examples, 706221 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 20:59:19,101 : INFO : EPOCH 12 - PROGRESS: at 53.39% examples, 708136 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:59:20,112 : INFO : EPOCH 12 - PROGRESS: at 56.53% examples, 708590 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 20:59:21,125 : INFO : EPOCH 12 - PROGRESS: at 59.62% examples, 708523 words/s, in_qsize 96, out_qsize 3
# 2024-05-07 20:59:22,127 : INFO : EPOCH 12 - PROGRESS: at 62.55% examples, 705583 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 20:59:23,132 : INFO : EPOCH 12 - PROGRESS: at 65.55% examples, 704058 words/s, in_qsize 93, out_qsize 0
# 2024-05-07 20:59:24,144 : INFO : EPOCH 12 - PROGRESS: at 68.41% examples, 701652 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 20:59:25,150 : INFO : EPOCH 12 - PROGRESS: at 71.60% examples, 702410 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 20:59:26,150 : INFO : EPOCH 12 - PROGRESS: at 74.44% examples, 701007 words/s, in_qsize 96, out_qsize 3
# 2024-05-07 20:59:27,162 : INFO : EPOCH 12 - PROGRESS: at 77.72% examples, 702749 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 20:59:28,172 : INFO : EPOCH 12 - PROGRESS: at 81.06% examples, 705271 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 20:59:29,176 : INFO : EPOCH 12 - PROGRESS: at 84.10% examples, 705193 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 20:59:30,188 : INFO : EPOCH 12 - PROGRESS: at 87.31% examples, 706079 words/s, in_qsize 96, out_qsize 3
# 2024-05-07 20:59:31,190 : INFO : EPOCH 12 - PROGRESS: at 90.56% examples, 708049 words/s, in_qsize 93, out_qsize 2
# ...
# 2024-05-07 21:29:14,562 : INFO : EPOCH 15 - PROGRESS: at 76.99% examples, 717335 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:29:15,587 : INFO : EPOCH 15 - PROGRESS: at 80.17% examples, 717461 words/s, in_qsize 92, out_qsize 2
# 2024-05-07 21:29:16,648 : INFO : EPOCH 15 - PROGRESS: at 83.74% examples, 719774 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:29:17,663 : INFO : EPOCH 15 - PROGRESS: at 87.09% examples, 721439 words/s, in_qsize 94, out_qsize 3
# 2024-05-07 21:29:18,707 : INFO : EPOCH 15 - PROGRESS: at 90.44% examples, 722521 words/s, in_qsize 95, out_qsize 4
# 2024-05-07 21:29:19,718 : INFO : EPOCH 15 - PROGRESS: at 93.93% examples, 724961 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:29:20,734 : INFO : EPOCH 15 - PROGRESS: at 97.31% examples, 726534 words/s, in_qsize 63, out_qsize 0
# 2024-05-07 21:29:21,291 : INFO : EPOCH 15: training on 23279529 raw words (22951015 effective words) took 31.3s, 732970 effective words/s
# 2024-05-07 21:29:22,324 : INFO : EPOCH 16 - PROGRESS: at 2.10% examples, 482305 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 21:29:23,368 : INFO : EPOCH 16 - PROGRESS: at 5.88% examples, 662256 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 21:29:24,368 : INFO : EPOCH 16 - PROGRESS: at 8.99% examples, 683370 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:29:25,406 : INFO : EPOCH 16 - PROGRESS: at 12.33% examples, 694657 words/s, in_qsize 94, out_qsize 5
# 2024-05-07 21:29:26,466 : INFO : EPOCH 16 - PROGRESS: at 15.83% examples, 707894 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 21:29:27,467 : INFO : EPOCH 16 - PROGRESS: at 19.14% examples, 716907 words/s, in_qsize 92, out_qsize 3
# 2024-05-07 21:29:28,488 : INFO : EPOCH 16 - PROGRESS: at 22.76% examples, 730948 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 21:29:29,491 : INFO : EPOCH 16 - PROGRESS: at 25.92% examples, 729020 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 21:29:30,522 : INFO : EPOCH 16 - PROGRESS: at 29.39% examples, 732370 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 21:29:31,533 : INFO : EPOCH 16 - PROGRESS: at 32.79% examples, 736848 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 21:29:32,555 : INFO : EPOCH 16 - PROGRESS: at 35.92% examples, 733545 words/s, in_qsize 96, out_qsize 3
# 2024-05-07 21:29:33,591 : INFO : EPOCH 16 - PROGRESS: at 38.88% examples, 726966 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 21:29:34,621 : INFO : EPOCH 16 - PROGRESS: at 42.06% examples, 725633 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 21:29:35,656 : INFO : EPOCH 16 - PROGRESS: at 45.24% examples, 724542 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 21:29:36,695 : INFO : EPOCH 16 - PROGRESS: at 48.54% examples, 723402 words/s, in_qsize 91, out_qsize 8
# 2024-05-07 21:29:37,697 : INFO : EPOCH 16 - PROGRESS: at 51.82% examples, 725258 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 21:29:38,716 : INFO : EPOCH 16 - PROGRESS: at 55.14% examples, 725631 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 21:29:39,745 : INFO : EPOCH 16 - PROGRESS: at 58.24% examples, 724447 words/s, in_qsize 96, out_qsize 2
# 2024-05-07 21:29:40,779 : INFO : EPOCH 16 - PROGRESS: at 61.64% examples, 725309 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 21:29:41,790 : INFO : EPOCH 16 - PROGRESS: at 65.11% examples, 727723 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 21:29:42,800 : INFO : EPOCH 16 - PROGRESS: at 68.30% examples, 727319 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 21:29:43,872 : INFO : EPOCH 16 - PROGRESS: at 71.30% examples, 723202 words/s, in_qsize 96, out_qsize 15
# 2024-05-07 21:29:44,929 : INFO : EPOCH 16 - PROGRESS: at 75.07% examples, 728086 words/s, in_qsize 94, out_qsize 7
# 2024-05-07 21:29:45,958 : INFO : EPOCH 16 - PROGRESS: at 78.39% examples, 728718 words/s, in_qsize 95, out_qsize 6
# 2024-05-07 21:29:46,969 : INFO : EPOCH 16 - PROGRESS: at 81.89% examples, 731735 words/s, in_qsize 96, out_qsize 2
# 2024-05-07 21:29:47,972 : INFO : EPOCH 16 - PROGRESS: at 85.29% examples, 733617 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:29:49,090 : INFO : EPOCH 16 - PROGRESS: at 88.55% examples, 731354 words/s, in_qsize 89, out_qsize 6
# 2024-05-07 21:29:50,092 : INFO : EPOCH 16 - PROGRESS: at 92.13% examples, 734792 words/s, in_qsize 90, out_qsize 1
# 2024-05-07 21:29:51,100 : INFO : EPOCH 16 - PROGRESS: at 95.37% examples, 734676 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 21:29:52,101 : INFO : EPOCH 16 - PROGRESS: at 99.06% examples, 738802 words/s, in_qsize 21, out_qsize 3
# 2024-05-07 21:29:52,166 : INFO : EPOCH 16: training on 23279529 raw words (22951015 effective words) took 30.8s, 743992 effective words/s
# 2024-05-07 21:29:53,192 : INFO : EPOCH 17 - PROGRESS: at 2.15% examples, 495071 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 21:29:54,194 : INFO : EPOCH 17 - PROGRESS: at 5.69% examples, 659260 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 21:29:55,211 : INFO : EPOCH 17 - PROGRESS: at 8.97% examples, 687328 words/s, in_qsize 92, out_qsize 4
# 2024-05-07 21:29:56,213 : INFO : EPOCH 17 - PROGRESS: at 12.34% examples, 706340 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:29:57,253 : INFO : EPOCH 17 - PROGRESS: at 15.87% examples, 722119 words/s, in_qsize 96, out_qsize 2
# 2024-05-07 21:29:58,261 : INFO : EPOCH 17 - PROGRESS: at 19.33% examples, 732857 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 21:29:59,261 : INFO : EPOCH 17 - PROGRESS: at 22.92% examples, 746898 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 21:30:00,273 : INFO : EPOCH 17 - PROGRESS: at 26.29% examples, 748052 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 21:30:01,284 : INFO : EPOCH 17 - PROGRESS: at 29.72% examples, 750091 words/s, in_qsize 96, out_qsize 4
# 2024-05-07 21:30:02,286 : INFO : EPOCH 17 - PROGRESS: at 33.23% examples, 755306 words/s, in_qsize 95, out_qsize 2
# 2024-05-07 21:30:03,290 : INFO : EPOCH 17 - PROGRESS: at 36.55% examples, 755865 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 21:30:04,306 : INFO : EPOCH 17 - PROGRESS: at 40.09% examples, 759466 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 21:30:05,320 : INFO : EPOCH 17 - PROGRESS: at 43.52% examples, 761161 words/s, in_qsize 96, out_qsize 4
# 2024-05-07 21:30:06,335 : INFO : EPOCH 17 - PROGRESS: at 47.08% examples, 763298 words/s, in_qsize 93, out_qsize 4
# 2024-05-07 21:30:07,364 : INFO : EPOCH 17 - PROGRESS: at 50.49% examples, 762491 words/s, in_qsize 93, out_qsize 3
# 2024-05-07 21:30:08,371 : INFO : EPOCH 17 - PROGRESS: at 54.03% examples, 764704 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:30:09,383 : INFO : EPOCH 17 - PROGRESS: at 57.07% examples, 760761 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:30:10,415 : INFO : EPOCH 17 - PROGRESS: at 60.38% examples, 759624 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:30:11,418 : INFO : EPOCH 17 - PROGRESS: at 63.59% examples, 757359 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:30:12,420 : INFO : EPOCH 17 - PROGRESS: at 66.62% examples, 753345 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 21:30:13,431 : INFO : EPOCH 17 - PROGRESS: at 69.91% examples, 753369 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:30:14,442 : INFO : EPOCH 17 - PROGRESS: at 73.00% examples, 750886 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 21:30:15,465 : INFO : EPOCH 17 - PROGRESS: at 76.16% examples, 749492 words/s, in_qsize 90, out_qsize 5
# 2024-05-07 21:30:16,465 : INFO : EPOCH 17 - PROGRESS: at 79.63% examples, 751727 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 21:30:17,474 : INFO : EPOCH 17 - PROGRESS: at 83.00% examples, 752419 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 21:30:18,489 : INFO : EPOCH 17 - PROGRESS: at 86.14% examples, 751349 words/s, in_qsize 92, out_qsize 3
# 2024-05-07 21:30:19,502 : INFO : EPOCH 17 - PROGRESS: at 89.42% examples, 751187 words/s, in_qsize 91, out_qsize 1
# 2024-05-07 21:30:20,513 : INFO : EPOCH 17 - PROGRESS: at 92.58% examples, 750334 words/s, in_qsize 90, out_qsize 5
# 2024-05-07 21:30:21,524 : INFO : EPOCH 17 - PROGRESS: at 96.15% examples, 752250 words/s, in_qsize 90, out_qsize 2
# 2024-05-07 21:30:22,342 : INFO : EPOCH 17: training on 23279529 raw words (22951015 effective words) took 30.2s, 761228 effective words/s
# 2024-05-07 21:30:23,373 : INFO : EPOCH 18 - PROGRESS: at 2.11% examples, 483479 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 21:30:24,375 : INFO : EPOCH 18 - PROGRESS: at 5.62% examples, 648495 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 21:30:25,436 : INFO : EPOCH 18 - PROGRESS: at 8.96% examples, 676580 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 21:30:26,459 : INFO : EPOCH 18 - PROGRESS: at 12.50% examples, 703895 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 21:30:27,471 : INFO : EPOCH 18 - PROGRESS: at 15.73% examples, 710486 words/s, in_qsize 96, out_qsize 2
# 2024-05-07 21:30:28,473 : INFO : EPOCH 18 - PROGRESS: at 18.98% examples, 716023 words/s, in_qsize 96, out_qsize 6
# 2024-05-07 21:30:29,489 : INFO : EPOCH 18 - PROGRESS: at 22.74% examples, 734789 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 21:30:30,512 : INFO : EPOCH 18 - PROGRESS: at 25.92% examples, 731631 words/s, in_qsize 94, out_qsize 3
# 2024-05-07 21:30:31,533 : INFO : EPOCH 18 - PROGRESS: at 29.22% examples, 731414 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 21:30:32,534 : INFO : EPOCH 18 - PROGRESS: at 32.08% examples, 724210 words/s, in_qsize 96, out_qsize 2
# 2024-05-07 21:30:33,552 : INFO : EPOCH 18 - PROGRESS: at 35.04% examples, 718947 words/s, in_qsize 92, out_qsize 3
# 2024-05-07 21:30:34,561 : INFO : EPOCH 18 - PROGRESS: at 38.38% examples, 722206 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 21:30:35,570 : INFO : EPOCH 18 - PROGRESS: at 41.66% examples, 724012 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 21:30:36,614 : INFO : EPOCH 18 - PROGRESS: at 44.65% examples, 719779 words/s, in_qsize 95, out_qsize 8
# 2024-05-07 21:30:37,630 : INFO : EPOCH 18 - PROGRESS: at 48.04% examples, 721332 words/s, in_qsize 92, out_qsize 3
# 2024-05-07 21:30:38,636 : INFO : EPOCH 18 - PROGRESS: at 51.63% examples, 727258 words/s, in_qsize 88, out_qsize 1
# 2024-05-07 21:30:39,664 : INFO : EPOCH 18 - PROGRESS: at 54.72% examples, 724905 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 21:30:40,667 : INFO : EPOCH 18 - PROGRESS: at 58.12% examples, 727984 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:30:41,669 : INFO : EPOCH 18 - PROGRESS: at 61.41% examples, 728822 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:30:42,711 : INFO : EPOCH 18 - PROGRESS: at 64.91% examples, 730009 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 21:30:43,735 : INFO : EPOCH 18 - PROGRESS: at 68.18% examples, 729969 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 21:30:44,763 : INFO : EPOCH 18 - PROGRESS: at 71.45% examples, 730113 words/s, in_qsize 96, out_qsize 7
# 2024-05-07 21:30:45,775 : INFO : EPOCH 18 - PROGRESS: at 75.04% examples, 734084 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:30:46,864 : INFO : EPOCH 18 - PROGRESS: at 78.47% examples, 733820 words/s, in_qsize 96, out_qsize 5
# 2024-05-07 21:30:47,910 : INFO : EPOCH 18 - PROGRESS: at 82.10% examples, 736781 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 21:30:48,931 : INFO : EPOCH 18 - PROGRESS: at 85.62% examples, 739076 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 21:30:49,963 : INFO : EPOCH 18 - PROGRESS: at 88.83% examples, 738537 words/s, in_qsize 87, out_qsize 8
# 2024-05-07 21:30:51,008 : INFO : EPOCH 18 - PROGRESS: at 92.33% examples, 739969 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 21:30:52,014 : INFO : EPOCH 18 - PROGRESS: at 95.86% examples, 742015 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 21:30:52,923 : INFO : EPOCH 18: training on 23279529 raw words (22951015 effective words) took 30.6s, 751153 effective words/s
# 2024-05-07 21:30:53,969 : INFO : EPOCH 19 - PROGRESS: at 2.15% examples, 485622 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:30:54,991 : INFO : EPOCH 19 - PROGRESS: at 5.85% examples, 664934 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:30:55,995 : INFO : EPOCH 19 - PROGRESS: at 9.11% examples, 690900 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 21:30:57,033 : INFO : EPOCH 19 - PROGRESS: at 12.50% examples, 704923 words/s, in_qsize 96, out_qsize 2
# 2024-05-07 21:30:58,085 : INFO : EPOCH 19 - PROGRESS: at 15.91% examples, 713528 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 21:30:59,089 : INFO : EPOCH 19 - PROGRESS: at 19.22% examples, 721276 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:31:00,090 : INFO : EPOCH 19 - PROGRESS: at 22.06% examples, 710918 words/s, in_qsize 96, out_qsize 4
# 2024-05-07 21:31:01,116 : INFO : EPOCH 19 - PROGRESS: at 24.96% examples, 702323 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:31:02,136 : INFO : EPOCH 19 - PROGRESS: at 28.05% examples, 701203 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 21:31:03,163 : INFO : EPOCH 19 - PROGRESS: at 31.20% examples, 701827 words/s, in_qsize 95, out_qsize 5
# 2024-05-07 21:31:04,200 : INFO : EPOCH 19 - PROGRESS: at 34.38% examples, 700887 words/s, in_qsize 96, out_qsize 2
# 2024-05-07 21:31:05,206 : INFO : EPOCH 19 - PROGRESS: at 37.16% examples, 695402 words/s, in_qsize 93, out_qsize 2
# 2024-05-07 21:31:06,210 : INFO : EPOCH 19 - PROGRESS: at 40.29% examples, 697508 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:31:07,234 : INFO : EPOCH 19 - PROGRESS: at 43.07% examples, 692111 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:31:08,274 : INFO : EPOCH 19 - PROGRESS: at 46.23% examples, 692400 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 21:31:09,281 : INFO : EPOCH 19 - PROGRESS: at 49.39% examples, 692999 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:31:10,302 : INFO : EPOCH 19 - PROGRESS: at 52.52% examples, 693558 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:31:11,309 : INFO : EPOCH 19 - PROGRESS: at 55.71% examples, 695456 words/s, in_qsize 89, out_qsize 1
# 2024-05-07 21:31:12,332 : INFO : EPOCH 19 - PROGRESS: at 58.80% examples, 695216 words/s, in_qsize 94, out_qsize 2
# 2024-05-07 21:31:13,358 : INFO : EPOCH 19 - PROGRESS: at 62.23% examples, 698257 words/s, in_qsize 94, out_qsize 1
# 2024-05-07 21:31:14,369 : INFO : EPOCH 19 - PROGRESS: at 65.42% examples, 698744 words/s, in_qsize 95, out_qsize 1
# 2024-05-07 21:31:15,390 : INFO : EPOCH 19 - PROGRESS: at 68.72% examples, 700571 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:31:16,470 : INFO : EPOCH 19 - PROGRESS: at 72.11% examples, 701302 words/s, in_qsize 91, out_qsize 4
# 2024-05-07 21:31:17,477 : INFO : EPOCH 19 - PROGRESS: at 75.33% examples, 703257 words/s, in_qsize 91, out_qsize 4
# 2024-05-07 21:31:18,483 : INFO : EPOCH 19 - PROGRESS: at 78.75% examples, 706634 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:31:19,530 : INFO : EPOCH 19 - PROGRESS: at 81.96% examples, 706883 words/s, in_qsize 96, out_qsize 6
# 2024-05-07 21:31:20,550 : INFO : EPOCH 19 - PROGRESS: at 85.49% examples, 710199 words/s, in_qsize 96, out_qsize 0
# 2024-05-07 21:31:21,551 : INFO : EPOCH 19 - PROGRESS: at 88.76% examples, 711857 words/s, in_qsize 93, out_qsize 0
# 2024-05-07 21:31:22,576 : INFO : EPOCH 19 - PROGRESS: at 91.95% examples, 712345 words/s, in_qsize 95, out_qsize 0
# 2024-05-07 21:31:23,618 : INFO : EPOCH 19 - PROGRESS: at 95.53% examples, 714710 words/s, in_qsize 96, out_qsize 1
# 2024-05-07 21:31:24,618 : INFO : EPOCH 19 - PROGRESS: at 99.54% examples, 721662 words/s, in_qsize 10, out_qsize 1
# 2024-05-07 21:31:24,645 : INFO : EPOCH 19: training on 23279529 raw words (22951015 effective words) took 31.7s, 724113 effective words/s
# 2024-05-07 21:31:24,647 : INFO : Doc2Vec lifecycle event {'msg': 'training on 465590580 raw words (459020300 effective words) took 613.8s, 747781 effective words/s', 'datetime': '2024-05-07T21:31:24.647031', 'gensim': '4.3.2', 'python': '3.9.18 | packaged by conda-forge | (main, Dec 23 2023, 16:33:10) \n[GCC 12.3.0]', 'platform': 'Linux-4.15.0-213-generic-x86_64-with-glibc2.27', 'event': 'train'}
# Evaluating Doc2Vec<dm/c,d100,n5,w5,mc2,t48>
#
# 0.299000 Doc2Vec<dm/c,d100,n5,w5,mc2,t48>
#
#
# Evaluating Doc2Vec<dbow,d100,n5,mc2,t48>+Doc2Vec<dm/m,d100,n5,w10,mc2,t48>
#
# 0.10436 Doc2Vec<dbow,d100,n5,mc2,t48>+Doc2Vec<dm/m,d100,n5,w10,mc2,t48>
#
#
# Evaluating Doc2Vec<dbow,d100,n5,mc2,t48>+Doc2Vec<dm/c,d100,n5,w5,mc2,t48>
#
# 0.10476 Doc2Vec<dbow,d100,n5,mc2,t48>+Doc2Vec<dm/c,d100,n5,w5,mc2,t48>

# %% [markdown]
# Achieved Sentiment-Prediction Accuracy
# --------------------------------------
# Compare error rates achieved, best-to-worst

# %%
print("Err_rate Model")
for rate, name in sorted((rate, name) for name, rate in error_rates.items()):
    print(f"{rate} {name}")
# Out:
# Err_rate Model
# 0.10436 Doc2Vec<dbow,d100,n5,mc2,t48>+Doc2Vec<dm/m,d100,n5,w10,mc2,t48>
# 0.10452 Doc2Vec<dbow,d100,n5,mc2,t48>
# 0.10476 Doc2Vec<dbow,d100,n5,mc2,t48>+Doc2Vec<dm/c,d100,n5,w5,mc2,t48>
# 0.17032 Doc2Vec<dm/m,d100,n5,w10,mc2,t48>
# 0.299 Doc2Vec<dm/c,d100,n5,w5,mc2,t48>

# %% [markdown]
# In our testing, contrary to the results of the paper, on this problem,
# PV-DBOW alone performs as good as anything else. Concatenating vectors from
# different models only sometimes offers a tiny predictive improvement – and
# stays generally close to the best-performing solo model included.
#
# The best results achieved here are just around 10% error rate, still a long
# way from the paper's reported 7.42% error rate.
#
# (Other trials not shown, with larger vectors and other changes, also don't
# come close to the paper's reported value. Others around the net have reported
# a similar inability to reproduce the paper's best numbers. The PV-DM/C mode
# improves a bit with many more training epochs – but doesn't reach parity with
# PV-DBOW.)

# %% [markdown]
# Examining Results
# -----------------
#
# Let's look for answers to the following questions:
#
# #. Are inferred vectors close to the precalculated ones?
# #. Do close documents seem more related than distant ones?
# #. Do the word vectors show useful similarities?
# #. Are the word vectors from this dataset any good at analogies?

# %% [markdown]
# Are inferred vectors close to the precalculated ones?
# -----------------------------------------------------

# %%
doc_id = np.random.randint(len(simple_models[0].dv))  # Pick random doc; re-run cell for more examples
print(f'for doc {doc_id}...')
for model in simple_models:
    inferred_docvec = model.infer_vector(alldocs[doc_id].words)
    print(f'{model}:\n {model.dv.most_similar([inferred_docvec], topn=3)}')
# Out:
# for doc 67990...
# Doc2Vec<dbow,d100,n5,mc2,t48>:
#  [(67990, 0.9694914817810059), (64627, 0.6643124222755432), (74191, 0.6321359872817993)]
# Doc2Vec<dm/m,d100,n5,w10,mc2,t48>:
#  [(67990, 0.9226250052452087), (26538, 0.5970041155815125), (97970, 0.5921608209609985)]
# Doc2Vec<dm/c,d100,n5,w5,mc2,t48>:
#  [(67990, 0.7077532410621643), (53586, 0.4684329330921173), (90969, 0.46206676959991455)]

# %% [markdown]
# (Yes, here the stored vector from 20 epochs of training is usually one of the
# closest to a freshly-inferred vector for the same words. Defaults for
# inference may benefit from tuning for each dataset or model parameters.)

# %% [markdown]
# Do close documents seem more related than distant ones?
# -------------------------------------------------------

# %%
import random

doc_id = np.random.randint(len(simple_models[0].dv))  # pick random doc, re-run cell for more examples
model = random.choice(simple_models)  # and a random model
sims = model.dv.most_similar(doc_id, topn=len(model.dv))  # get *all* similar documents
print(f'TARGET ({doc_id}): «{" ".join(alldocs[doc_id].words)}»\n')
print(f'SIMILAR/DISSIMILAR DOCS PER MODEL {model}%s:\n')
for label, index in [('MOST', 0), ('MEDIAN', len(sims)//2), ('LEAST', len(sims) - 1)]:
    s = sims[index]
    i = sims[index][0]
    words = ' '.join(alldocs[i].words)
    print(f'{label} {s}: «{words}»\n')
# Out:
# TARGET (85049): «A Few years ago, I found this at a Flea Market, after catching the trailer on the VHS of The Wizard Of Gore years earlier. All I remembered was that it seemed like something worth the three dollars the guy was asking, but after years of being burned in my search for decent-bad cinema, I wasn't all that shocked to discover that Class Reunion Massacre is, in fact, not worth the three dollars I paid. I like old B-horror because it's different, because it's outlandish and rebellious, because it can be refreshing compared to all the big-budget, super-hero garbage of today. But none of that means anything if it puts you to sleep.<br /><br />Typical Horror plot. Some kid walks out of a lake, gets on a bus, and goes to Church, where we find a rather loud Priest doing his thing...<br /><br />and I'm sure all of this has something to do with the six "sinners" the story now revolves around. Four People I barely noticed, Mr. metro-fem, and a lesbian are headed to their 10 year high school reunion where they can sit around and eat, and "act", and wonder where the hell everyone's at. With the doors now locked, one by one, everyone is taken out by the redeemer, some guy who probably fancys himself some kind of righteous/sadistic chameleon, hence the killing in the name of God, and constant wardrobe changes. Feeling tired yet? <br /><br />Class Reunion Massacre is mostly made up of endless conversations and ironic killings meant to punish sins such as gluttony, and drinking too much. This film manages to be blasphemous against Christianity, as well as B-cinema. I expected very little, yet was somehow still disappointed. What I find most irritating about Class Reunion Massacre is I can almost detect a hint of potential somewhere in there. The atmosphere is all it has going for it. Ultimately, this is not a good horror movie, not a good B-movie, Class Reunion Massacre, for the lack of a better word, is a failure. Actually, I wouldn't mind a DVD release, with some audio commentary, which might shed a little light, because I just know I missed something. I don't get it. There's way too many positive reviews for this... come to think of it, I'm wasting my time here. I could be reviewing something worthwhile, like Nightmare In A Damaged Brain...»
#
# SIMILAR/DISSIMILAR DOCS PER MODEL Doc2Vec<dm/c,d100,n5,w5,mc2,t48>%s:
#
# MOST (18284, 0.4459972381591797): «This movie is possibly one of the most creative works of horror ever. It has everything you could want... suspense, drama, comedy, confusing subplots, native americans, brain eating... If you're looking for the be-all, end-all of brainsucking movies, look no further. The story of a man, bent on revenge. And how better to get it? "I know, I'll suck out their brains!" With great sound effects, and impressive special effects, I can't recommend this movie enough.»
#
# MEDIAN (51491, 0.0004385797365102917): «I rented Just Write for Valentine's Day, largely due to the reviews I read on this site (my adoration of Sherilyn Fenn had a little impact, also...). Most people thought it was a great date movie.<br /><br />You know the basis of the story if you've read the summary, so I won't repeat it here. Jeremy Piven, from TV's short-lived Cupid, plays the bus driver whose favorite actress is Amanda Clark (wonderfully played by Fenn). He brings the same appeal he did to Cupid - - funny and down-to-earth. He really makes you pull for his character.<br /><br />Sherilyn Fenn has one of the best roles of her career, even though it may not be much of a stretch (an actress playing an actress). She looks absolutely wonderful and, while I don't know what Sherilyn's like personally, gives Amanda such warmth and sincerity that it's hard NOT to fall in love with someone like her.<br /><br />The two of them have a really nice chemistry together. I wanted to see more of them as a couple. There were some nice supporting characters who added a lot to the story. There was the typical misunderstanding, but it was resolved in a nice way. Some reviews have stated that it was unrealistic for a famous movie star to fall for a guy like this, but I don't view that as a negative. First, all good romantic comedies have similar problems (Pretty Woman, Notting Hill, Sleepless in Seattle - - how realistic are they!?); they all resolve them in an interesting way, just like this movie does. Second, I enjoy putting myself in a movie ("How would I react in this situation?"), and this one allowed me to pretend that I was pursuing Amanda/Sherilyn - - that's what movies are for!<br /><br />In summary, (guys) don't view this as a chick flick just because it involves a love story. It's every bit as good as those I mentioned above. Rent this movie with someone you love and enjoy the ride. I actually watched it again the next day, and even fast-forwarded through it a third time to watch just the scenes between Piven and Fenn. It's special. My score: 10»
#
# LEAST (18590, -0.4424915015697479): «I chose "The English Patient" for a history extra credit assignment. I thought that this movie would be incredibly boring. Instead, it has become one of my favorites. It portrays life in WWII quite accurately, and the love story is amazing. The love story made the movie so incredible. I felt this interesting feeling, of passion or something. It made me want to watch the movie over and over again. Kristin Scott Thomas and Ralph Fiennes are amazing actors and the way they played their characters is amazing. The look wonderful together and actually seemed to be in love. I recommend this movie to anyone looking for a movie to watch as a leisure activity, or for an assignment.»

# %% [markdown]
# Somewhat, in terms of reviewer tone, movie genre, etc... the MOST
# cosine-similar docs usually seem more like the TARGET than the MEDIAN or
# LEAST... especially if the MOST has a cosine-similarity > 0.5. Re-run the
# cell to try another random target document.

# %% [markdown]
# Do the word vectors show useful similarities?
# ---------------------------------------------

# %%
import random

word_models = simple_models[:]

def pick_random_word(model, threshold=10):
    # pick a random word with a suitable number of occurences
    while True:
        word = random.choice(model.wv.index_to_key)
        if model.wv.get_vecattr(word, "count") > threshold:
            return word

target_word = pick_random_word(word_models[0])
# or uncomment below line, to just pick a word from the relevant domain:
# target_word = 'comedy/drama'

for model in word_models:
    print(f'target_word: {repr(target_word)} model: {model} similar words:')
    for i, (word, sim) in enumerate(model.wv.most_similar(target_word, topn=10), 1):
        print(f'    {i}. {sim:.2f} {repr(word)}')
    print()
# Out:
# target_word: 'teachers,' model: Doc2Vec<dbow,d100,n5,mc2,t48> similar words:
#     1. 0.42 'acquiesces'
#     2. 0.41 'on....just'
#     3. 0.41 'marries'
#     4. 0.41 'J.J'
#     5. 0.40 'forty-nine'
#     6. 0.40 'Romancing'
#     7. 0.39 'brake'
#     8. 0.39 'galled'
#     9. 0.39 'RUBBER'
#     10. 0.38 'in;'
#
# target_word: 'teachers,' model: Doc2Vec<dm/m,d100,n5,w10,mc2,t48> similar words:
#     1. 0.52 'cheerleaders,'
#     2. 0.52 'graduates'
#     3. 0.51 'crowd),'
#     4. 0.51 'fraternities'
#     5. 0.51 'pupils'
#     6. 0.50 'co-workers,'
#     7. 0.49 'neighbors,'
#     8. 0.49 'disapproval'
#     9. 0.49 'bratty,'
#     10. 0.49 'bigots'
#
# target_word: 'teachers,' model: Doc2Vec<dm/c,d100,n5,w5,mc2,t48> similar words:
#     1. 0.60 'sexuality,'
#     2. 0.59 'troops,'
#     3. 0.59 'prostitutes,'
#     4. 0.57 'employers,'
#     5. 0.57 'siblings,'
#     6. 0.57 'Presidents,'
#     7. 0.57 'glue,'
#     8. 0.56 'slaves,'
#     9. 0.56 'daughters,'
#     10. 0.55 'clothing,'

# %% [markdown]
# Do the DBOW words look meaningless? That's because the gensim DBOW model
# doesn't train word vectors – they remain at their random initialized values –
# unless you ask with the ``dbow_words=1`` initialization parameter. Concurrent
# word-training slows DBOW mode significantly, and offers little improvement
# (and sometimes a little worsening) of the error rate on this IMDB
# sentiment-prediction task, but may be appropriate on other tasks, or if you
# also need word-vectors.
#
# Words from DM models tend to show meaningfully similar words when there are
# many examples in the training data (as with 'plot' or 'actor'). (All DM modes
# inherently involve word-vector training concurrent with doc-vector training.)

# %% [markdown]
# Are the word vectors from this dataset any good at analogies?
# -------------------------------------------------------------

# %%
from gensim.test.utils import datapath
questions_filename = datapath('questions-words.txt')

# Note: this analysis takes many minutes
for model in word_models:
    score, sections = model.wv.evaluate_word_analogies(questions_filename)
    correct, incorrect = len(sections[-1]['correct']), len(sections[-1]['incorrect'])
    print(f'{model}: {float(correct*100)/(correct+incorrect):0.2f}%% correct ({correct} of {correct+incorrect}')
# Out:
# 2024-05-07 21:36:55,852 : INFO : Evaluating word analogies for top 300000 words in the model on /home/xgwei/miniconda3/envs/workenv/lib/python3.9/site-packages/gensim/test/test_data/questions-words.txt
# 2024-05-07 21:37:06,504 : INFO : capital-common-countries: 0.0% (0/420)
# 2024-05-07 21:37:29,797 : INFO : capital-world: 0.0% (0/902)
# 2024-05-07 21:37:31,960 : INFO : currency: 0.0% (0/86)
# 2024-05-07 21:38:11,312 : INFO : city-in-state: 0.0% (0/1510)
# 2024-05-07 21:38:24,420 : INFO : family: 0.0% (0/506)
# 2024-05-07 21:38:49,753 : INFO : gram1-adjective-to-adverb: 0.0% (0/992)
# 2024-05-07 21:39:09,077 : INFO : gram2-opposite: 0.0% (0/756)
# 2024-05-07 21:39:42,881 : INFO : gram3-comparative: 0.0% (0/1332)
# 2024-05-07 21:40:09,760 : INFO : gram4-superlative: 0.0% (0/1056)
# 2024-05-07 21:40:35,126 : INFO : gram5-present-participle: 0.0% (0/992)
# 2024-05-07 21:41:11,710 : INFO : gram6-nationality-adjective: 0.0% (0/1445)
# 2024-05-07 21:41:51,811 : INFO : gram7-past-tense: 0.0% (0/1560)
# 2024-05-07 21:42:22,592 : INFO : gram8-plural: 0.0% (0/1190)
# 2024-05-07 21:42:44,605 : INFO : gram9-plural-verbs: 0.0% (0/870)
# 2024-05-07 21:42:44,607 : INFO : Quadruplets with out-of-vocabulary words: 30.3%
# 2024-05-07 21:42:44,609 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2024-05-07 21:42:44,609 : INFO : Total accuracy: 0.0% (0/13617)
# 2024-05-07 21:42:44,992 : INFO : Evaluating word analogies for top 300000 words in the model on /home/xgwei/miniconda3/envs/workenv/lib/python3.9/site-packages/gensim/test/test_data/questions-words.txt
# Doc2Vec<dbow,d100,n5,mc2,t48>: 0.00%% correct (0 of 13617
# 2024-05-07 21:42:55,574 : INFO : capital-common-countries: 2.6% (11/420)
# 2024-05-07 21:43:18,275 : INFO : capital-world: 0.6% (5/902)
# 2024-05-07 21:43:20,394 : INFO : currency: 0.0% (0/86)
# 2024-05-07 21:43:58,232 : INFO : city-in-state: 0.4% (6/1510)
# 2024-05-07 21:44:11,818 : INFO : family: 36.8% (186/506)
# 2024-05-07 21:44:37,075 : INFO : gram1-adjective-to-adverb: 3.4% (34/992)
# 2024-05-07 21:44:55,866 : INFO : gram2-opposite: 6.7% (51/756)
# 2024-05-07 21:45:29,930 : INFO : gram3-comparative: 48.1% (641/1332)
# 2024-05-07 21:45:56,751 : INFO : gram4-superlative: 25.5% (269/1056)
# 2024-05-07 21:46:22,273 : INFO : gram5-present-participle: 23.5% (233/992)
# 2024-05-07 21:46:58,167 : INFO : gram6-nationality-adjective: 2.5% (36/1445)
# 2024-05-07 21:47:37,550 : INFO : gram7-past-tense: 29.6% (462/1560)
# 2024-05-07 21:48:07,749 : INFO : gram8-plural: 19.8% (236/1190)
# 2024-05-07 21:48:29,442 : INFO : gram9-plural-verbs: 44.8% (390/870)
# 2024-05-07 21:48:29,446 : INFO : Quadruplets with out-of-vocabulary words: 30.3%
# 2024-05-07 21:48:29,447 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2024-05-07 21:48:29,448 : INFO : Total accuracy: 18.8% (2560/13617)
# 2024-05-07 21:48:29,832 : INFO : Evaluating word analogies for top 300000 words in the model on /home/xgwei/miniconda3/envs/workenv/lib/python3.9/site-packages/gensim/test/test_data/questions-words.txt
# Doc2Vec<dm/m,d100,n5,w10,mc2,t48>: 18.80%% correct (2560 of 13617
# 2024-05-07 21:48:40,454 : INFO : capital-common-countries: 1.9% (8/420)
# 2024-05-07 21:49:02,551 : INFO : capital-world: 0.4% (4/902)
# 2024-05-07 21:49:04,721 : INFO : currency: 0.0% (0/86)
# 2024-05-07 21:49:41,891 : INFO : city-in-state: 0.1% (2/1510)
# 2024-05-07 21:49:54,906 : INFO : family: 36.6% (185/506)
# 2024-05-07 21:50:20,515 : INFO : gram1-adjective-to-adverb: 9.4% (93/992)
# 2024-05-07 21:50:39,657 : INFO : gram2-opposite: 3.3% (25/756)
# 2024-05-07 21:51:13,077 : INFO : gram3-comparative: 35.1% (467/1332)
# 2024-05-07 21:51:39,280 : INFO : gram4-superlative: 23.7% (250/1056)
# 2024-05-07 21:52:04,308 : INFO : gram5-present-participle: 37.2% (369/992)
# 2024-05-07 21:52:40,095 : INFO : gram6-nationality-adjective: 2.3% (33/1445)
# 2024-05-07 21:53:18,995 : INFO : gram7-past-tense: 27.2% (425/1560)
# 2024-05-07 21:53:49,800 : INFO : gram8-plural: 10.5% (125/1190)
# 2024-05-07 21:54:11,695 : INFO : gram9-plural-verbs: 48.9% (425/870)
# 2024-05-07 21:54:11,698 : INFO : Quadruplets with out-of-vocabulary words: 30.3%
# 2024-05-07 21:54:11,698 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2024-05-07 21:54:11,699 : INFO : Total accuracy: 17.7% (2411/13617)
# Doc2Vec<dm/c,d100,n5,w5,mc2,t48>: 17.71%% correct (2411 of 13617

# %% [markdown]
# Even though this is a tiny, domain-specific dataset, it shows some meager
# capability on the general word analogies – at least for the DM/mean and
# DM/concat models which actually train word vectors. (The untrained
# random-initialized words of the DBOW model of course fail miserably.)

# %%
import torch
save_path = "./data/doc2vec.model"
torch.save(simple_models, save_path)

# %%
save_path = "./data/doc2vec.model"
simple_models = torch.load(save_path)

# %%
for model in simple_models:
    print(f"\nEvaluating {model}")
    err_rate, err_count, test_count, predictor = error_rate_for_model(model, train_docs, test_docs)
    error_rates[str(model)] = err_rate
    print("\n%f %s\n" % (err_rate, model))
# Out:
# Evaluating Doc2Vec<dbow,d100,n5,mc2,t48>
#
# 0.104520 Doc2Vec<dbow,d100,n5,mc2,t48>
#
#
# Evaluating Doc2Vec<dm/m,d100,n5,w10,mc2,t48>
#
# 0.170320 Doc2Vec<dm/m,d100,n5,w10,mc2,t48>
#
#
# Evaluating Doc2Vec<dm/c,d100,n5,w5,mc2,t48>
#
# 0.299000 Doc2Vec<dm/c,d100,n5,w5,mc2,t48>
